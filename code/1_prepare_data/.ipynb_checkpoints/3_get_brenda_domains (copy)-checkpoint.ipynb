# %% [markdown]
# This notebook is identifying PFAM domains for all BRENDA sequences.<br/><br/>Copyright (C) 2020  Martin Engqvist Lab<br/>This program is free software: you can redistribute it and/or modify<br/>it under the terms of the GNU General Public License as published by<br/>the Free Software Foundation, either version 3 of the License, or<br/>(at your option) any later version.<br/>This program is distributed in the hope that it will be useful,<br/>but WITHOUT ANY WARRANTY; without even the implied warranty of<br/>MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the<br/>GNU General Public License for more details.<br/>You should have received a copy of the GNU General Public License<br/>along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %%
import os
from dotenv import load_dotenv, find_dotenv
from os.path import join, dirname, basename, exists, isdir

### Load environmental variables from the project root directory ###
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)

# now you can get the variables using their names

# Check whether a network drive has been specified
DATABASE = os.environ.get("NETWORK_URL")
if DATABASE == 'None':
    pass
else:
    pass
    #mount network drive here

# set up directory paths
CURRENT_DIR = os.getcwd()
PROJ = dirname(dotenv_path) # project root directory

DATA = join(PROJ, 'data') #data directory
RAW_EXTERNAL = join(DATA, 'raw_external') # external data raw directory
RAW_INTERNAL = join(DATA, 'raw_internal') # internal data raw directory
INTERMEDIATE = join(DATA, 'intermediate') # intermediate data directory
FINAL = join(DATA, 'final') # final data directory

RESULTS = join(PROJ, 'results') # output directory
FIGURES = join(RESULTS, 'figures') # figure output directory
PICTURES = join(RESULTS, 'pictures') # picture output directory


folder_name = 'brenda_domains'
if folder_name != '':
    #make folders if they don't exist
    if not exists(join(INTERMEDIATE, 'BRENDA_for_paper', folder_name)):
        os.makedirs(join(INTERMEDIATE, 'BRENDA_for_paper', folder_name))

print('Standard variables loaded, you are good to go!')
# Out:
# Standard variables loaded, you are good to go!

# %%
import os
import subprocess
from os.path import join, exists, getsize
import multiprocessing
import pandas as pd
import numpy as np

from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import time
import re


from tqdm import tqdm

# %% [markdown]
# ### Download the Pfam hmm file
# From database version 33.1

# %%
url = 'ftp://ftp.ebi.ac.uk/pub/databases/Pfam/releases/Pfam33.1/Pfam-A.hmm.gz'
outfile = join(INTERMEDIATE, 'BRENDA_for_paper', folder_name, 'Pfam-A.hmm.gz')


if not exists(outfile.replace('.gz', '')):
    # download the hmm file
    my_cmd = 'wget -O {} {}'.format(outfile, url)
    os.system(my_cmd)

    # unzip file
    my_cmd = 'gunzip {}'.format(outfile)
    os.system(my_cmd)

# %% [markdown]
# ### Go through fasta files and discover all Pfam domains

# %%
def worker(package):
    '''
    A worker to carry out the hmmsearch.
    '''
    fi, inpath, outpath, pfam_hmms = package

    fasta_file = join(inpath, fi)
    hmm_outfile = join(outpath, fi+'.out')

    if not exists(hmm_outfile):
        mycmd = 'hmmsearch -E 1e-15 --domtblout %s %s %s > tmp.out' % (hmm_outfile, pfam_hmms, fasta_file)
        os.system(mycmd)


        
def search_all(ecnum, reverse=False):
    '''
    Function for distributing the files on a number of workers.
    '''
    num_cores = multiprocessing.cpu_count()

    # define folders
    outpath = join(INTERMEDIATE, 'BRENDA_for_paper', folder_name)
    inpath = join(INTERMEDIATE, 'BRENDA_for_paper', 'ec_identity_clustering')
    pfam_hmms = join(outpath, 'Pfam-A.hmm')

    # run assemble a list of the file to run
    packages = []
    for fi in sorted(os.listdir(inpath), reverse=reverse):

        if not fi.startswith(ecnum):
            continue

        if not fi.endswith('90_augmented.fasta'):
            continue

        packages.append((fi, inpath, outpath, pfam_hmms))

    # distribute work on the cores
    with multiprocessing.Pool(processes=num_cores) as pool:
        results = pool.map(worker, packages)



def parse_hmm_output(filepath, ec):
    '''
    Parse an hmm output file and return as pandas data frame.
    '''
    data = {'ec':[], 'uid':[], 'hmm_model':[], 'pfam':[], 'hmm_model_len':[], 'hmm_match_from':[],
            'hmm_match_to':[], 'hmm_match_coverage':[], 'match_evalue':[], 'gene_match_from':[],
            'gene_match_to':[]}

    with open(filepath, 'r') as f:
        for line in f:
            if line.startswith('#'):
                continue

            parts = line.strip().split()
            if len(parts) < 10:
                print(line)

            uid = parts[0].split(';')[0]

            dom_name = parts[3]
            pfam = parts[4]

            evalue = parts[6]

            qlen = parts[5]
            hmm_from = parts[15]
            hmm_to = parts[16]
            coverage = (int(hmm_to)-int(hmm_from))/int(qlen)

            ali_from = parts[17]
            ali_to = parts[18]

            if coverage >= 0.35:
                data['ec'].append(ec)
                data['uid'].append(uid)
                data['hmm_model'].append(dom_name)
                data['pfam'].append(pfam)
                data['hmm_model_len'].append(qlen)
                data['hmm_match_from'].append(hmm_from)
                data['hmm_match_to'].append(hmm_to)
                data['hmm_match_coverage'].append('%.2f' % float(coverage))
                data['match_evalue'].append(evalue)
                data['gene_match_from'].append(ali_from)
                data['gene_match_to'].append(ali_to)

    return pd.DataFrame(data)



def get_pfam_domains():
    '''
    Go through all the augmented fasta files and predict Pfam domains.
    '''

    # align all the matches
    for ec_start in tqdm(range(1, 8)):
        ec_start = str(ec_start)
        search_all(ecnum=ec_start, reverse=False)

    # parse the outfiles
    filepath = join(INTERMEDIATE, 'BRENDA_for_paper', folder_name)
    outfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'pfam_hmm_results.tsv')
    
    all_domain_data = None
    for fi in tqdm(sorted(os.listdir(filepath))):

        if not fi.endswith('.fasta.out'):
            continue

        if getsize(join(filepath, fi)) == 0:
            continue

        print(fi)

        # parse outputs
        ec = fi.split('_')[0]
        hmm_data = parse_hmm_output(join(filepath, fi), ec)

        # add to the main data
        if all_domain_data is None:
            all_domain_data = hmm_data
        else:
            all_domain_data = all_domain_data.append(hmm_data)

    all_domain_data.to_csv(outfile, sep='\t', index=False)
    
    
# run analysis
outfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'pfam_hmm_results.tsv')
if not exists(outfile):
    get_pfam_domains()

# %% [markdown]
# ### There are sometimes several predictions for the same region of a protein, but we only want to keep one

# %%
df = pd.read_csv(outfile, sep='\t')

display(df.head())
display(df.tail())
display(df.describe())
# Out:
#           ec         uid      hmm_model        pfam  hmm_model_len  \
# 0  1.1.1.100  A0A137SKR6      3Beta_HSD  PF01073.20            280
# 1  1.1.1.100  A0A0F4VT46       ABC_tran  PF00005.28            137
# 2  1.1.1.100      F8GQY5  Abhydrolase_1  PF00561.21            257
# 3  1.1.1.100  A0A0N1NPA0  Abhydrolase_1  PF00561.21            257
# 4  1.1.1.100      F8GQY5  Abhydrolase_6   PF12697.8            220
#
#    hmm_match_from  hmm_match_to  hmm_match_coverage  match_evalue  \
# 0               1           158                0.56  2.200000e-16
# 1               2           137                0.99  8.300000e-29
# 2               2           111                0.42  2.900000e-27
# 3               1           252                0.98  1.100000e-20
# 4               1           216                0.98  3.200000e-22
#
#    gene_match_from  gene_match_to
# 0                4            166
# 1               23            177
# 2               78            187
# 3               29            280
# 4               79            310
#               ec     uid       hmm_model        pfam  hmm_model_len  \
# 8553087  7.6.2.9  D4YFX4           OpuAC  PF04069.13            257
# 8553088  7.6.2.9  E0QLH2           OpuAC  PF04069.13            257
# 8553089  7.6.2.9  S2K9H2           OpuAC  PF04069.13            257
# 8553090  7.6.2.9  G0QK58         Pkinase  PF00069.26            264
# 8553091  7.6.2.9  G0QK58  PK_Tyr_Ser-Thr  PF07714.18            259
#
#          hmm_match_from  hmm_match_to  hmm_match_coverage  match_evalue  \
# 8553087               3           257                0.99  7.500000e-48
# 8553088               3           257                0.99  3.200000e-46
# 8553089             160           257                0.38  1.700000e-30
# 8553090               1           240                0.91  5.100000e-55
# 8553091               2           215                0.82  7.500000e-34
#
#          gene_match_from  gene_match_to
# 8553087               39            304
# 8553088               10            275
# 8553089                4            102
# 8553090               84            325
# 8553091               85            295
#        hmm_model_len  hmm_match_from  hmm_match_to  hmm_match_coverage  \
# count   8.553092e+06    8.553092e+06  8.553092e+06        8.553092e+06
# mean    1.902124e+02    6.333660e+00  1.831750e+02        9.299050e-01
# std     1.128297e+02    2.147707e+01  1.096854e+02        1.244718e-01
# min     1.000000e+01    1.000000e+00  6.000000e+00        3.500000e-01
# 25%     1.080000e+02    1.000000e+00  1.040000e+02        9.400000e-01
# 50%     1.660000e+02    2.000000e+00  1.590000e+02        9.800000e-01
# 75%     2.550000e+02    3.000000e+00  2.440000e+02        9.900000e-01
# max     2.048000e+03    9.120000e+02  2.048000e+03        1.000000e+00
#
#        match_evalue  gene_match_from  gene_match_to
# count  8.553092e+06     8.553092e+06   8.553092e+06
# mean   1.301662e-17     1.898545e+02   3.716371e+02
# std    7.983808e-17     4.874608e+02   4.835598e+02
# min    0.000000e+00     1.000000e+00   1.000000e+01
# 25%    7.300000e-65     1.200000e+01   1.910000e+02
# 50%    8.600000e-40     6.000000e+01   2.990000e+02
# 75%    4.100000e-25     2.540000e+02   4.430000e+02
# max    1.000000e-15     3.515000e+04   3.521000e+04

# %% [markdown]
# ### First figure out what the cutoff should be in terms of what is an overlap

# %%
def test_overlap(pos1, pos2, cutoff):
    '''
    Find out whether two defined regions overlap or not.
    Overlap is defined True when at least one of the domains 
    overlap with the other above a certain fraction of the whole.
    '''
    pos1 = [int(s) for s in pos1]
    pos2 = [int(s) for s in pos2]
    both_pairs = sorted([pos1, pos2])
    
    # simplest case, they do not overlap at all
    if both_pairs[0][1] < both_pairs[1][0]:
        return False
    
    else:
        # get overlap part
        overlap_region = both_pairs[0][1] - both_pairs[1][0]
        
        # fraction of first domain
        frac_first = overlap_region / (both_pairs[0][1] - both_pairs[0][0])
                          
        # fraction of second domain
        frac_second = overlap_region / (both_pairs[1][1] - both_pairs[1][0])
        
        if max(frac_first, frac_second) > cutoff:
            #print(both_pairs, True, max(frac_first, frac_second))
            return True
        else:
            #print(both_pairs, False, max(frac_first, frac_second))
            return False
    

    
    
def remove_overlaps(data, cutoff):
    '''
    When domains overlap (as defined by the cutoff level), 
    keep only the domain with the best e-value score.
    '''
    overlaps = [True]
    while any(overlaps):
        
        start_end_pairs = list(zip(data.gene_match_from.values, data.gene_match_to.values))
        e_vals = data.match_evalue.values
        e_vals = e_vals.astype(np.float) 

        
        for i in tqdm(range(len(start_end_pairs))):
            overlaps = []
            for j in range(len(start_end_pairs[i+1:])):

                overlaps.append(test_overlap(start_end_pairs[i], start_end_pairs[i+1+j], cutoff))

            # prepend true or false for the first sequence, depending on whether there was an overlap
            if any(overlaps):
                overlaps = [False for s in range(i)] + [True] + overlaps

                # from the ones with an overlap, what is the position of the one with the lowest e-value
                overlap_e_vals = e_vals[overlaps]

                idx = overlap_e_vals.argmin()
                #print(overlaps)
                #print(overlap_e_vals)
                #print(i+idx)


                # flip the one that said true but had the smallest e-value
                overlaps[i+idx] = False

                # invert the list to flip True vs False
                overlaps = [not i for i in overlaps]

                # filter the data to keep all the ones that originally said False, but now say true
                data = data[overlaps]
                #print(data)
                break
                
    return data


    
# test a range of cutoff values to figure out which one is best
cutoff_vals = [s/100 for s in range(5, 105, 5)]
motifs = []
for cutoff in tqdm(cutoff_vals):
    
    temp_data_filepath = join(INTERMEDIATE, 'BRENDA_for_paper', 'motifs_result_{}.tsv'.format(cutoff))
    if not exists(temp_data_filepath):
        non_redundant_data = df.groupby('uid').apply(lambda x: remove_overlaps(x, cutoff=cutoff))
    else:
        non_redundant_data = pd.read_csv(temp_data_filepath, sep='\t')
        
    motifs.append(non_redundant_data.uid.count())


print('Unfiltered domain number: %s' % df.uid.count())



# plot the data
plt.scatter([s * 100 for s in cutoff_vals], motifs)
plt.xlabel('Pairwise domain overlap required for removal (%)')
plt.ylabel('Domain number')
plt.xticks(np.arange(0, 100+10, 10))
plt.title('Domain overlap sensitivity analysis')


plt.savefig(join(FIGURES, 'domain_sensitivity_analysis.png'), dpi=300, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)

plt.savefig(join(FIGURES, 'domain_sensitivity_analysis.png'), facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3819.95it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8719.97it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 43577.18it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15650.39it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18131.00it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15141.89it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 19152.07it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11522.81it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7752.87it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9776.93it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1717.57it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16844.59it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13617.87it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14364.05it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 156.31it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13774.40it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8473.34it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1229.64it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16384.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5461.33it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 180.71it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14926.35it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 1081.15it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 14012.15it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 1855.48it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8160.12it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 8097.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8542.37it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17367.72it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8289.14it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16288.56it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15477.14it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4946.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1766.02it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15196.75it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 11008.67it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7869.24it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 10512.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4514.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8905.10it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7653.84it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 12557.80it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13127.71it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8439.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4854.52it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16131.94it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8577.31it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6978.88it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7096.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13066.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6307.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12446.01it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 27060.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1800.90it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5737.76it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15947.92it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9554.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8630.26it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6909.89it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18558.87it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1325.63it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12787.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13530.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12748.64it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14691.08it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 598.84it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7796.10it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16777.22it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 2057.04it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8981.38it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9619.96it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13378.96it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 327.86it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16644.06it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18275.83it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9986.44it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10485.76it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1385.17it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12748.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14820.86it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14315.03it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8559.80it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14004.35it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8594.89it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7436.71it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7345.54it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14217.98it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8081.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1460.41it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4665.52it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6990.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9822.73it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15887.52it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10433.59it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12945.38it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 3758.90it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18864.94it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10433.59it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14315.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
#  12%|█▎        | 1/8 [00:00<00:00, 740.78it/s]
#
#  50%|█████     | 3/6 [00:00<00:00, 2052.68it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 38479.85it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9489.38it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8338.58it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14027.77it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 25420.02it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 44620.26it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6932.73it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8405.42it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9320.68it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9157.87it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7530.17it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8962.19it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 468.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10106.76it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8848.74it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10010.27it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10922.67it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10433.59it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9157.87it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17367.72it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12372.58it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 494.15it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 770.23it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 12652.50it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 12446.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9915.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9157.87it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10356.31it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8112.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10180.35it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6808.94it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9320.68it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9137.92it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9754.20it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10459.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10034.22it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15738.48it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16844.59it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15827.56it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10485.76it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9078.58it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7884.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9962.72it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10512.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2608.40it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13797.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8456.26it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18641.35it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9098.27it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 17822.82it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12409.18it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9000.65it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8035.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8388.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13573.80it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11748.75it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 21845.33it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11932.59it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 16384.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 18724.57it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18236.10it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4092.00it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9532.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15448.63it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5793.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8272.79it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9300.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9642.08it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10155.70it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9576.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5005.14it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 477.00it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 10459.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11650.84it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7884.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12595.51it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8289.14it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 16980.99it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 473.29it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3622.02it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 984.58it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9198.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10538.45it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15563.28it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2416.07it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 30247.38it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10922.67it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 958.77it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
#
#  25%|██▌       | 2/8 [00:00<00:00, 1583.35it/s]
#
# 100%|██████████| 7/7 [00:00<00:00, 50360.43it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10538.45it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 584.86it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 23921.89it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9664.29it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10131.17it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 531.33it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14339.50it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2402.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5729.92it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 39199.10it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17225.07it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 24314.81it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2492.16it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7157.52it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12520.31it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 37008.56it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18682.87it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5622.39it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8507.72it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11586.48it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12826.62it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13273.11it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 669.59it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12018.06it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13025.79it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6512.89it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7476.48it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 24059.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6533.18it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9664.29it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 10631.95it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9892.23it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 23388.31it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8665.92it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9776.93it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9320.68it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5377.31it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 296.52it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14820.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7423.55it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7530.17it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10330.80it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13934.56it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16946.68it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10407.70it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9754.20it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10180.35it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9300.01it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17260.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9177.91it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10538.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9799.78it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 30652.65it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17154.62it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16578.28it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11244.78it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16384.00it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16513.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4319.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12557.80it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6820.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6689.48it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8176.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10810.06it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 28728.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10230.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1270.62it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11214.72it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9362.29it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8848.74it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13981.01it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16100.98it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7854.50it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14413.42it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 440.72it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 21959.71it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 879.31it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 16777.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6754.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11335.96it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 503.64it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 12671.61it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 24209.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10433.59it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10180.35it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15709.00it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#  14%|█▍        | 1/7 [00:00<00:00, 457.59it/s]
#
#  33%|███▎      | 2/6 [00:00<00:00, 1169.63it/s]
#
#  60%|██████    | 3/5 [00:00<00:00, 1015.41it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 22104.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5343.06it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8630.26it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3953.16it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 218.51it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13508.23it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 299.14it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15006.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7710.12it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1224.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9709.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13273.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1472.20it/s]
#
#   0%|          | 0/14 [00:00<?, ?it/s]
#
#   0%|          | 0/12 [00:00<?, ?it/s]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9554.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8886.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4288.65it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15709.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8240.28it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7989.15it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16644.06it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 611.95it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 515.84it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14873.42it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16611.10it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 33689.19it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9300.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10618.49it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9642.08it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9467.95it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9341.43it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15033.35it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13252.15it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 23607.71it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10485.76it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5548.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9845.78it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8981.38it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17331.83it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6150.01it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15857.48it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5349.88it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8525.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6502.80it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 35544.95it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9238.56it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 21583.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6932.73it/s]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#  11%|█         | 1/9 [00:00<00:00, 633.68it/s]
#
#  25%|██▌       | 2/8 [00:00<00:00, 1843.65it/s]
#
#  43%|████▎     | 3/7 [00:00<00:00, 950.08it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 24600.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9383.23it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9619.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8793.09it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9597.95it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10837.99it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7530.17it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7219.11it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15505.74it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7194.35it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8035.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8943.08it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6921.29it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15141.89it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8830.11it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 17949.95it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9000.65it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8305.55it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19691.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15196.75it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13066.37it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 23497.50it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11459.85it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14614.30it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9868.95it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16416.06it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11125.47it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13189.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13189.64it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9510.89it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2857.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4319.57it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 23607.71it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 21959.71it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14873.42it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6967.28it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 899.29it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 20971.52it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 12710.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13981.01it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5540.69it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8019.70it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8289.14it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9320.68it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10699.76it/s]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 26083.98it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8594.89it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15391.94it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13443.28it/s]
#
# 100%|██████████| 7/7 [00:00<00:00, 46455.90it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13797.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13400.33it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15420.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9554.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8612.53it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8612.53it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 24769.51it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8719.97it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9218.25it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9039.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11428.62it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11848.32it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 9686.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9532.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9986.44it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17015.43it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8848.74it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8577.31it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22857.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9258.95it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7281.78it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16710.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15709.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7194.35it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18921.67it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6831.11it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16039.40it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7989.15it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7182.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8665.92it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17015.43it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14315.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8305.55it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10131.17it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 14529.92it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 25890.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9915.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10058.28it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 6223.00it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15448.63it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7319.90it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17962.76it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8683.86it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 22671.91it/s]
#
#  55%|█████▍    | 6/11 [00:00<00:00, 1938.67it/s]
#
#  70%|███████   | 7/10 [00:00<00:00, 2478.07it/s]
#
# 100%|██████████| 9/9 [00:00<00:00, 40677.52it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8256.50it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15621.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4728.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 23629.88it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6141.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10280.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11522.81it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10230.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7626.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7219.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7557.30it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11650.84it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13819.78it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 10605.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13842.59it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7294.44it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8577.31it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 3137.10it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 913.00it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14315.03it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 674.33it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16777.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11781.75it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18157.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9238.56it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17476.27it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14122.24it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7710.12it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13706.88it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9799.78it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13189.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13842.59it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6732.43it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14513.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13617.87it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 10740.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6605.20it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12192.74it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13148.29it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 33112.93it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9058.97it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 25890.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9489.38it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 34952.53it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19737.90it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 4549.14it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9218.25it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18157.16it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15448.63it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 21788.59it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2614.90it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13273.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13573.80it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11915.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15827.56it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13934.56it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 228.93it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11949.58it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8192.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9822.73it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19418.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10754.63it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8886.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7543.71it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 743.14it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8338.58it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12087.33it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18078.90it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7767.23it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15279.80it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 280.48it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15709.00it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 27413.75it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7958.83it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13066.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4946.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9686.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10727.12it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13400.33it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15709.00it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 7854.50it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16480.57it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16100.98it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10979.85it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10727.12it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8525.01it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 28244.47it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10894.30it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 4621.82it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7810.62it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9383.23it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 16889.81it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10230.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2049.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8719.97it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8065.97it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 20229.76it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16480.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13315.25it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 19846.86it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16384.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5769.33it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14716.86it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11634.69it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9078.58it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9177.91it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5315.97it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 32870.72it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 20901.85it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8594.89it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8559.80it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 473.99it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15947.92it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9619.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9845.78it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9845.78it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17734.90it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9619.96it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15307.68it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13357.66it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10565.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13573.80it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 24528.09it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13107.20it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:00<00:00, 322.89it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 1532.73it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 38130.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13797.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15477.14it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14513.16it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 35444.82it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15363.75it/s]
#
#  29%|██▊       | 2/7 [00:00<00:00, 380.02it/s]
#
#  40%|████      | 2/5 [00:00<00:00, 886.56it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 41425.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11335.96it/s]
# 100%|██████████| 4/4 [00:00<00:00, 42690.12it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 24576.00it/s]
#
#  14%|█▍        | 1/7 [00:00<00:00, 868.75it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 53092.46it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10782.27it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18724.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8388.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9686.61it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14051.27it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6700.17it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10618.49it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 1008.37it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18236.10it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10082.46it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10330.80it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10727.12it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18001.30it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10866.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8683.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9686.61it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15650.39it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9822.73it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7219.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9137.92it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8019.70it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7145.32it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 21583.04it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 22590.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1945.41it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8756.38it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 32768.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9597.95it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16163.02it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 25811.10it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14614.30it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14639.80it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8683.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 16710.37it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 30066.70it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 7847.15it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11275.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6932.73it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9118.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7061.12it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8738.13it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 18001.30it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15477.14it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 53498.78it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5412.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10010.27it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 29746.84it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9098.27it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 32181.36it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11066.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7557.30it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8981.38it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2611.65it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9425.40it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14847.09it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8112.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9137.92it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 21902.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13400.33it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13066.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3705.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9157.87it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16100.98it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16980.99it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10058.28it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5203.85it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7898.88it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 25191.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8208.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9218.25it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 26602.35it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14794.72it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2064.13it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14820.86it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 12905.55it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9238.56it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9118.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8981.38it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18040.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9532.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9799.78it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 15621.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9320.68it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5090.17it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19108.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10255.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 469.42it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10407.70it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 40853.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 17848.10it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 238.07it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11831.61it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15592.21it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14873.42it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 15887.52it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8962.19it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14290.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9754.20it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12372.58it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11915.64it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 25015.73it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2880.70it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9000.65it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 310.71it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 4319.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 17119.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12671.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 16644.06it/s]
#
#   0%|          | 0/21 [00:00<?, ?it/s]
#
#   0%|          | 0/15 [00:00<?, ?it/s]
#
#   0%|          | 0/11 [00:00<?, ?it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18450.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13315.25it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6462.72it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 22509.68it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18423.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7653.84it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9799.78it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15335.66it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 23464.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9576.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8683.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4006.02it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 379.97it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 24291.34it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 831.21it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 531.66it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14004.35it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9554.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12557.80it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 31223.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13025.79it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14027.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7695.97it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10782.27it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6955.73it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6668.21it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22857.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13486.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5737.76it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9218.25it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9238.56it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 2642.91it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9300.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5433.04it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16777.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11459.85it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15363.75it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7738.57it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22733.36it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8097.11it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13315.25it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12826.62it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9962.72it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 25471.48it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 30690.03it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18196.55it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9642.08it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9467.95it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2030.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9576.04it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16777.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9020.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7096.96it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 552.32it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18040.02it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 34285.86it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18641.35it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9177.91it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11335.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11554.56it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13046.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6636.56it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9845.78it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7206.71it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 5092.23it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13273.11it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 1805.94it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8630.26it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7530.17it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8738.13it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8905.10it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 21013.55it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18117.94it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4350.94it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 20789.61it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16416.06it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12372.58it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:00<00:00, 418.55it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 38245.93it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13486.51it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22857.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13443.28it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12787.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8559.80it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17189.77it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16980.99it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18117.94it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19328.59it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6700.17it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 23763.76it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 21959.71it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 1076.57it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 21219.08it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10330.80it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18850.80it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7973.96it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4739.33it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15738.48it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12409.18it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6553.60it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12228.29it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15087.42it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13706.88it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9300.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9118.05it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13443.28it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11366.68it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10180.35it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14513.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9489.38it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11491.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11881.88it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15363.75it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15252.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7256.58it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10180.35it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15768.06it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 27962.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12520.31it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7194.35it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8793.09it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8355.19it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15709.00it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8473.34it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8355.19it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1122.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9320.68it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16578.28it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9300.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4500.33it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 12826.62it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1179.83it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15857.48it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17260.51it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9554.22it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16611.10it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9576.04it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9489.38it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18436.50it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7584.64it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 17623.13it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 17050.02it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 29641.72it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 16777.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8648.05it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17084.74it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15679.64it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8830.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9362.29it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18275.83it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11586.48it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7913.78it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2128.01it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8439.24it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19463.13it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11522.81it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11305.40it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9320.68it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9489.38it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16710.37it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 700.51it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 19630.13it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16611.10it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8405.42it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9686.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8176.03it/s]
#
# ...
#
# 100%|██████████| 2/2 [00:00<00:00, 15978.30it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14027.77it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 29167.62it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13189.64it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#  17%|█▋        | 1/6 [00:00<00:00, 572.99it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18950.17it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13107.20it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15827.56it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13797.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7543.71it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13443.28it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 33465.19it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12671.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13066.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12710.01it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 8943.08it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16039.40it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7397.36it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10330.80it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10866.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3705.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1302.98it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7612.17it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5753.50it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14364.05it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7169.75it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 15768.06it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16163.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10010.27it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14513.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3637.73it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 16320.25it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 29127.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 15650.39it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22919.69it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22489.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2690.38it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13189.64it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12409.18it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12865.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8144.28it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9576.04it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 16889.81it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22429.43it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 8738.13it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 321.23it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 7731.44it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 18808.54it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8683.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8192.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11650.84it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5440.08it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 23899.17it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 6615.62it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 9388.48it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2400.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5336.26it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7681.88it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10866.07it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14315.03it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#  14%|█▍        | 1/7 [00:00<00:00, 465.83it/s]
#
#  33%|███▎      | 2/6 [00:00<00:00, 1819.26it/s]
#
#  60%|██████    | 3/5 [00:00<00:00, 3427.65it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 22133.53it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6017.65it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9000.65it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10866.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10230.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11650.84it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12905.55it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11814.94it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 31068.92it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12865.96it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 7639.90it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3734.91it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8192.00it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 11397.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8793.09it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8289.14it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8081.51it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5769.33it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8405.42it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1574.44it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14027.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 5146.39it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14899.84it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 14624.49it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 10512.04it/s]
#
#  57%|█████▋    | 4/7 [00:00<00:00, 656.05it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 35365.13it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 11640.07it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 23003.50it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3865.72it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3127.74it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9425.40it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 4796.23it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 25771.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6831.11it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1582.16it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2678.36it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9799.78it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 32922.32it/s]
#
#  17%|█▋        | 1/6 [00:00<00:00, 242.08it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 28197.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7825.19it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18586.28it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:00<00:00, 352.94it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 1161.37it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 18289.12it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7345.54it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 8914.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7096.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4739.33it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9098.27it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8224.13it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 23831.27it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9619.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9078.58it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9822.73it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7681.88it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 13066.37it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17512.75it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9279.43it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 16194.22it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16480.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7710.12it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11066.77it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14364.05it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3382.50it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:00<00:00, 450.66it/s]
#
#  50%|█████     | 2/4 [00:00<00:00, 939.58it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 32181.36it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 4966.61it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4686.37it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 13617.87it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12483.05it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16288.56it/s]
#
#  67%|██████▋   | 4/6 [00:00<00:00, 1738.75it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 41040.16it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 497.78it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22857.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 12446.01it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 21902.37it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 22250.95it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17225.07it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6909.89it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19878.22it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 8738.13it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 6004.73it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 24385.49it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4911.36it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 789.00it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 11335.96it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4854.52it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10034.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6668.21it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1909.11it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19021.79it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10034.22it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 14388.69it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3024.01it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7543.71it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4975.45it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10407.70it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 14266.34it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3177.50it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 320.81it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 19553.86it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 6009.03it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9137.92it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 23003.50it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 573.62it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8559.80it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9098.27it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16480.57it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 23215.70it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9177.91it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 2360.33it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8612.53it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11397.57it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8924.05it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16946.68it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 20068.44it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 3869.28it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 7767.23it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16844.59it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 17084.74it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 477.49it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 9425.40it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  33%|███▎      | 1/3 [00:00<00:00, 768.05it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 631.48it/s]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8439.24it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 1851.79it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 34521.02it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 8224.13it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10485.76it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 10034.22it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 4072.14it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 21509.25it/s]
#
#   0%|          | 0/20 [02:22<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f5021c21255c> in <module>
#      84 motifs = []
#      85 for cutoff in tqdm(cutoff_vals):
# ---> 86     non_redundant_data = df.groupby('uid').apply(lambda x: remove_overlaps(x, cutoff=cutoff))
#      87     motifs.append(non_redundant_data.uid.count())
#      88
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     733         with option_context("mode.chained_assignment", None):
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#     737                 # gh-20949
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     749
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#     753         return self._wrap_applied_output(
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     170         ):
#     171             try:
# --> 172                 result_values, mutated = splitter.fast_apply(f, group_keys)
#     173
#     174             except libreduction.InvalidApply as err:
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/pandas/core/groupby/ops.py in fast_apply(self, f, names)
#     929
#     930         sdata = self._get_sorted_data()
# --> 931         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#     932
#     933     def _chop(self, sdata: DataFrame, slice_obj: slice) -> DataFrame:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# <ipython-input-11-f5021c21255c> in <lambda>(x)
#      84 motifs = []
#      85 for cutoff in tqdm(cutoff_vals):
# ---> 86     non_redundant_data = df.groupby('uid').apply(lambda x: remove_overlaps(x, cutoff=cutoff))
#      87     motifs.append(non_redundant_data.uid.count())
#      88
#
# <ipython-input-11-f5021c21255c> in remove_overlaps(data, cutoff)
#      46
#      47
# ---> 48         for i in tqdm(range(len(start_end_pairs))):
#      49             overlaps = []
#      50             for j in range(len(start_end_pairs[i+1:])):
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/tqdm/std.py in __init__(self, iterable, desc, total, leave, file, ncols, mininterval, maxinterval, miniters, ascii, disable, unit, unit_scale, dynamic_ncols, smoothing, bar_format, initial, position, postfix, unit_divisor, write_bytes, lock_args, nrows, gui, **kwargs)
#    1046             # Initialize the screen printer
#    1047             self.sp = self.status_printer(self.fp)
# -> 1048             self.refresh(lock_args=self.lock_args)
#    1049
#    1050         # Init the time counter
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/tqdm/std.py in refresh(self, nolock, lock_args)
#    1334             else:
#    1335                 self._lock.acquire()
# -> 1336         self.display()
#    1337         if not nolock:
#    1338             self._lock.release()
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/tqdm/std.py in display(self, msg, pos)
#    1466
#    1467         if pos:
# -> 1468             self.moveto(pos)
#    1469         self.sp(self.__repr__() if msg is None else msg)
#    1470         if pos:
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/tqdm/std.py in moveto(self, n)
#    1423         # TODO: private method
#    1424         self.fp.write(_unicode('\n' * n + _term_move_up() * -n))
# -> 1425         self.fp.flush()
#    1426
#    1427     @property
#
# ~/miniconda3/envs/pt/lib/python3.7/site-packages/ipykernel/iostream.py in flush(self)
#     349                 self.pub_thread.schedule(evt.set)
#     350                 # and give a timeout to avoid
# --> 351                 if not evt.wait(self.flush_timeout):
#     352                     # write directly to __stderr__ instead of warning because
#     353                     # if this is happening sys.stderr may be the problem.
#
# ~/miniconda3/envs/pt/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/miniconda3/envs/pt/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Now remove redundant domains using the most appropriate cutoff

# %%
# filter out overlapping domains using pre-determined cutoff value
non_redundant_data = all_genome_data.groupby('uid').apply(lambda x: remove_overlaps(x, cutoff=0.2))

# write file to disk
non_redundant_data.to_csv(join(INTERMEDIATE, 'BRENDA_for_paper', 'pfam_hmm_results_non-redundant.tsv'), sep='\t', index=False)

# %% [markdown]
# ### x

# %%
df.groupby('uid')

# %% [markdown]
# # Other approach

# %% [markdown]
# ### Download Pfam pre-calculated domain data

# %%
url = 'ftp://ftp.ebi.ac.uk/pub/databases/Pfam/releases/Pfam33.1/Pfam-A.full.uniprot.gz'
outfile = join(RAW_EXTERNAL, 'BRENDA_for_paper', 'Pfam-A.full.uniprot.gz')

if not exists(outfile.replace('.gz', '')):
    # download the hmm file
    my_cmd = 'wget -O {} {}'.format(outfile, url)
    os.system(my_cmd)

    # unzip file
    my_cmd = 'gunzip {}'.format(outfile)
    os.system(my_cmd)

# %% [markdown]
# ### Get all uniprot identifiers from fasta files

# %%
def get_identifiers():
    '''
    Function for distributing the files on a number of workers.
    '''
    # define folder
    inpath = join(INTERMEDIATE, 'BRENDA_for_paper', 'ec_identity_clustering')

    # run assemble a list of the file to run
    data = {}
    for fi in sorted(os.listdir(inpath)):

        if not fi.endswith('90_augmented.fasta'):
            continue

        # print(fi)

        with open(join(inpath, fi), 'r') as f:
            for line in f:
                # only look at header lines
                if line.startswith('>'):
                    line_data = line.lstrip('>').rstrip().split(';')
                    uid = line_data[0]

                    data[uid] = []

    print('{} identifiers'.format(len(data.keys())))

    return data


data = get_identifiers()
# Out:
#   1%|          | 245/37060 [00:00<00:15, 2448.96it/s]
# 1.1.1.100_clustered_sequences_90_augmented.fasta
# 1.1.1.101_clustered_sequences_90_augmented.fasta
# 1.1.1.102_clustered_sequences_90_augmented.fasta
# 1.1.1.103_clustered_sequences_90_augmented.fasta
# 1.1.1.104_clustered_sequences_90_augmented.fasta
# 1.1.1.105_clustered_sequences_90_augmented.fasta
# 1.1.1.107_clustered_sequences_90_augmented.fasta
# 1.1.1.108_clustered_sequences_90_augmented.fasta
# 1.1.1.109_clustered_sequences_90_augmented.fasta
# 1.1.1.10_clustered_sequences_90_augmented.fasta
# 1.1.1.110_clustered_sequences_90_augmented.fasta
# 1.1.1.112_clustered_sequences_90_augmented.fasta
# 1.1.1.113_clustered_sequences_90_augmented.fasta
# 1.1.1.114_clustered_sequences_90_augmented.fasta
# 1.1.1.115_clustered_sequences_90_augmented.fasta
# 1.1.1.116_clustered_sequences_90_augmented.fasta
# 1.1.1.117_clustered_sequences_90_augmented.fasta
# 1.1.1.118_clustered_sequences_90_augmented.fasta
# 1.1.1.119_clustered_sequences_90_augmented.fasta
# 1.1.1.11_clustered_sequences_90_augmented.fasta
# 1.1.1.120_clustered_sequences_90_augmented.fasta
# 1.1.1.121_clustered_sequences_90_augmented.fasta
# 1.1.1.122_clustered_sequences_90_augmented.fasta
# 1.1.1.123_clustered_sequences_90_augmented.fasta
# 1.1.1.124_clustered_sequences_90_augmented.fasta
# 1.1.1.125_clustered_sequences_90_augmented.fasta
# 1.1.1.126_clustered_sequences_90_augmented.fasta
# 1.1.1.127_clustered_sequences_90_augmented.fasta
# 1.1.1.128_clustered_sequences_90_augmented.fasta
# 1.1.1.129_clustered_sequences_90_augmented.fasta
# 1.1.1.12_clustered_sequences_90_augmented.fasta
# 1.1.1.130_clustered_sequences_90_augmented.fasta
# 1.1.1.131_clustered_sequences_90_augmented.fasta
# 1.1.1.132_clustered_sequences_90_augmented.fasta
# 1.1.1.133_clustered_sequences_90_augmented.fasta
# 1.1.1.135_clustered_sequences_90_augmented.fasta
# 1.1.1.136_clustered_sequences_90_augmented.fasta
# 1.1.1.137_clustered_sequences_90_augmented.fasta
# 1.1.1.138_clustered_sequences_90_augmented.fasta
# 1.1.1.139_clustered_sequences_90_augmented.fasta
# 1.1.1.13_clustered_sequences_90_augmented.fasta
# 1.1.1.140_clustered_sequences_90_augmented.fasta
# 1.1.1.141_clustered_sequences_90_augmented.fasta
# 1.1.1.142_clustered_sequences_90_augmented.fasta
# 1.1.1.143_clustered_sequences_90_augmented.fasta
# 1.1.1.144_clustered_sequences_90_augmented.fasta
# 1.1.1.145_clustered_sequences_90_augmented.fasta
# 1.1.1.146_clustered_sequences_90_augmented.fasta
# 1.1.1.147_clustered_sequences_90_augmented.fasta
# 1.1.1.148_clustered_sequences_90_augmented.fasta
# 1.1.1.149_clustered_sequences_90_augmented.fasta
# 1.1.1.14_clustered_sequences_90_augmented.fasta
# 1.1.1.152_clustered_sequences_90_augmented.fasta
# 1.1.1.153_clustered_sequences_90_augmented.fasta
# 1.1.1.154_clustered_sequences_90_augmented.fasta
# 1.1.1.155_clustered_sequences_90_augmented.fasta
# 1.1.1.156_clustered_sequences_90_augmented.fasta
# 1.1.1.157_clustered_sequences_90_augmented.fasta
# 1.1.1.158_clustered_sequences_90_augmented.fasta
# 1.1.1.159_clustered_sequences_90_augmented.fasta
# 1.1.1.15_clustered_sequences_90_augmented.fasta
# 1.1.1.161_clustered_sequences_90_augmented.fasta
# 1.1.1.162_clustered_sequences_90_augmented.fasta
# 1.1.1.163_clustered_sequences_90_augmented.fasta
# 1.1.1.165_clustered_sequences_90_augmented.fasta
# 1.1.1.166_clustered_sequences_90_augmented.fasta
# 1.1.1.168_clustered_sequences_90_augmented.fasta
# 1.1.1.169_clustered_sequences_90_augmented.fasta
# 1.1.1.16_clustered_sequences_90_augmented.fasta
# 1.1.1.170_clustered_sequences_90_augmented.fasta
# 1.1.1.171_clustered_sequences_90_augmented.fasta
# 1.1.1.172_clustered_sequences_90_augmented.fasta
# 1.1.1.173_clustered_sequences_90_augmented.fasta
# 1.1.1.174_clustered_sequences_90_augmented.fasta
# 1.1.1.175_clustered_sequences_90_augmented.fasta
# 1.1.1.176_clustered_sequences_90_augmented.fasta
# 1.1.1.178_clustered_sequences_90_augmented.fasta
# 1.1.1.179_clustered_sequences_90_augmented.fasta
# 1.1.1.17_clustered_sequences_90_augmented.fasta
# 1.1.1.180_clustered_sequences_90_augmented.fasta
# 1.1.1.181_clustered_sequences_90_augmented.fasta
# 1.1.1.182_clustered_sequences_90_augmented.fasta
# 1.1.1.183_clustered_sequences_90_augmented.fasta
# 1.1.1.184_clustered_sequences_90_augmented.fasta
# 1.1.1.185_clustered_sequences_90_augmented.fasta
# 1.1.1.187_clustered_sequences_90_augmented.fasta
# 1.1.1.188_clustered_sequences_90_augmented.fasta
# 1.1.1.189_clustered_sequences_90_augmented.fasta
# 1.1.1.18_clustered_sequences_90_augmented.fasta
# 1.1.1.190_clustered_sequences_90_augmented.fasta
# 1.1.1.191_clustered_sequences_90_augmented.fasta
# 1.1.1.192_clustered_sequences_90_augmented.fasta
# 1.1.1.193_clustered_sequences_90_augmented.fasta
# 1.1.1.194_clustered_sequences_90_augmented.fasta
# 1.1.1.195_clustered_sequences_90_augmented.fasta
# 1.1.1.197_clustered_sequences_90_augmented.fasta
# 1.1.1.198_clustered_sequences_90_augmented.fasta
# 1.1.1.19_clustered_sequences_90_augmented.fasta
# 1.1.1.1_clustered_sequences_90_augmented.fasta
# 1.1.1.200_clustered_sequences_90_augmented.fasta
# 1.1.1.201_clustered_sequences_90_augmented.fasta
# 1.1.1.202_clustered_sequences_90_augmented.fasta
# 1.1.1.203_clustered_sequences_90_augmented.fasta
# 1.1.1.204_clustered_sequences_90_augmented.fasta
# 1.1.1.205_clustered_sequences_90_augmented.fasta
# 1.1.1.206_clustered_sequences_90_augmented.fasta
# 1.1.1.207_clustered_sequences_90_augmented.fasta
# 1.1.1.208_clustered_sequences_90_augmented.fasta
# 1.1.1.209_clustered_sequences_90_augmented.fasta
# 1.1.1.20_clustered_sequences_90_augmented.fasta
# 1.1.1.210_clustered_sequences_90_augmented.fasta
# 1.1.1.211_clustered_sequences_90_augmented.fasta
# 1.1.1.213_clustered_sequences_90_augmented.fasta
# 1.1.1.214_clustered_sequences_90_augmented.fasta
# 1.1.1.215_clustered_sequences_90_augmented.fasta
# 1.1.1.216_clustered_sequences_90_augmented.fasta
# 1.1.1.218_clustered_sequences_90_augmented.fasta
# 1.1.1.219_clustered_sequences_90_augmented.fasta
# 1.1.1.21_clustered_sequences_90_augmented.fasta
# 1.1.1.220_clustered_sequences_90_augmented.fasta
# 1.1.1.221_clustered_sequences_90_augmented.fasta
# 1.1.1.223_clustered_sequences_90_augmented.fasta
# 1.1.1.224_clustered_sequences_90_augmented.fasta
# 1.1.1.225_clustered_sequences_90_augmented.fasta
# 1.1.1.227_clustered_sequences_90_augmented.fasta
# 1.1.1.22_clustered_sequences_90_augmented.fasta
#   2%|▏         | 810/37060 [00:00<00:16, 2216.51it/s]
# 1.1.1.232_clustered_sequences_90_augmented.fasta
# 1.1.1.233_clustered_sequences_90_augmented.fasta
# 1.1.1.234_clustered_sequences_90_augmented.fasta
# 1.1.1.235_clustered_sequences_90_augmented.fasta
# 1.1.1.236_clustered_sequences_90_augmented.fasta
# 1.1.1.237_clustered_sequences_90_augmented.fasta
# 1.1.1.238_clustered_sequences_90_augmented.fasta
# 1.1.1.239_clustered_sequences_90_augmented.fasta
# 1.1.1.23_clustered_sequences_90_augmented.fasta
# 1.1.1.241_clustered_sequences_90_augmented.fasta
# 1.1.1.242_clustered_sequences_90_augmented.fasta
# 1.1.1.243_clustered_sequences_90_augmented.fasta
# 1.1.1.244_clustered_sequences_90_augmented.fasta
# 1.1.1.245_clustered_sequences_90_augmented.fasta
# 1.1.1.246_clustered_sequences_90_augmented.fasta
# 1.1.1.247_clustered_sequences_90_augmented.fasta
# 1.1.1.248_clustered_sequences_90_augmented.fasta
# 1.1.1.249_clustered_sequences_90_augmented.fasta
# 1.1.1.24_clustered_sequences_90_augmented.fasta
# 1.1.1.250_clustered_sequences_90_augmented.fasta
# 1.1.1.251_clustered_sequences_90_augmented.fasta
# 1.1.1.252_clustered_sequences_90_augmented.fasta
# 1.1.1.253_clustered_sequences_90_augmented.fasta
# 1.1.1.255_clustered_sequences_90_augmented.fasta
# 1.1.1.256_clustered_sequences_90_augmented.fasta
# 1.1.1.257_clustered_sequences_90_augmented.fasta
# 1.1.1.258_clustered_sequences_90_augmented.fasta
# 1.1.1.25_clustered_sequences_90_augmented.fasta
# 1.1.1.260_clustered_sequences_90_augmented.fasta
# 1.1.1.261_clustered_sequences_90_augmented.fasta
# 1.1.1.262_clustered_sequences_90_augmented.fasta
# 1.1.1.263_clustered_sequences_90_augmented.fasta
# 1.1.1.264_clustered_sequences_90_augmented.fasta
# 1.1.1.265_clustered_sequences_90_augmented.fasta
# 1.1.1.266_clustered_sequences_90_augmented.fasta
# 1.1.1.267_clustered_sequences_90_augmented.fasta
# 1.1.1.268_clustered_sequences_90_augmented.fasta
# 1.1.1.269_clustered_sequences_90_augmented.fasta
# 1.1.1.26_clustered_sequences_90_augmented.fasta
# 1.1.1.270_clustered_sequences_90_augmented.fasta
# 1.1.1.271_clustered_sequences_90_augmented.fasta
# 1.1.1.272_clustered_sequences_90_augmented.fasta
# 1.1.1.274_clustered_sequences_90_augmented.fasta
# 1.1.1.275_clustered_sequences_90_augmented.fasta
# 1.1.1.276_clustered_sequences_90_augmented.fasta
# 1.1.1.27_clustered_sequences_90_augmented.fasta
# 1.1.1.281_clustered_sequences_90_augmented.fasta
# 1.1.1.282_clustered_sequences_90_augmented.fasta
# 1.1.1.283_clustered_sequences_90_augmented.fasta
# 1.1.1.284_clustered_sequences_90_augmented.fasta
# 1.1.1.285_clustered_sequences_90_augmented.fasta
# 1.1.1.286_clustered_sequences_90_augmented.fasta
# 1.1.1.287_clustered_sequences_90_augmented.fasta
# 1.1.1.288_clustered_sequences_90_augmented.fasta
# 1.1.1.289_clustered_sequences_90_augmented.fasta
# 1.1.1.28_clustered_sequences_90_augmented.fasta
# 1.1.1.290_clustered_sequences_90_augmented.fasta
# 1.1.1.291_clustered_sequences_90_augmented.fasta
# 1.1.1.292_clustered_sequences_90_augmented.fasta
# 1.1.1.293_clustered_sequences_90_augmented.fasta
# 1.1.1.294_clustered_sequences_90_augmented.fasta
# 1.1.1.295_clustered_sequences_90_augmented.fasta
# 1.1.1.298_clustered_sequences_90_augmented.fasta
# 1.1.1.299_clustered_sequences_90_augmented.fasta
# 1.1.1.29_clustered_sequences_90_augmented.fasta
# 1.1.1.2_clustered_sequences_90_augmented.fasta
# 1.1.1.300_clustered_sequences_90_augmented.fasta
# 1.1.1.301_clustered_sequences_90_augmented.fasta
# 1.1.1.302_clustered_sequences_90_augmented.fasta
# 1.1.1.303_clustered_sequences_90_augmented.fasta
# 1.1.1.304_clustered_sequences_90_augmented.fasta
# 1.1.1.305_clustered_sequences_90_augmented.fasta
# 1.1.1.306_clustered_sequences_90_augmented.fasta
# 1.1.1.307_clustered_sequences_90_augmented.fasta
# 1.1.1.308_clustered_sequences_90_augmented.fasta
# 1.1.1.309_clustered_sequences_90_augmented.fasta
# 1.1.1.30_clustered_sequences_90_augmented.fasta
# 1.1.1.310_clustered_sequences_90_augmented.fasta
# 1.1.1.311_clustered_sequences_90_augmented.fasta
# 1.1.1.312_clustered_sequences_90_augmented.fasta
# 1.1.1.313_clustered_sequences_90_augmented.fasta
# 1.1.1.314_clustered_sequences_90_augmented.fasta
# 1.1.1.315_clustered_sequences_90_augmented.fasta
# 1.1.1.316_clustered_sequences_90_augmented.fasta
# 1.1.1.317_clustered_sequences_90_augmented.fasta
# 1.1.1.318_clustered_sequences_90_augmented.fasta
# 1.1.1.319_clustered_sequences_90_augmented.fasta
# 1.1.1.31_clustered_sequences_90_augmented.fasta
# 1.1.1.320_clustered_sequences_90_augmented.fasta
# 1.1.1.321_clustered_sequences_90_augmented.fasta
# 1.1.1.322_clustered_sequences_90_augmented.fasta
# 1.1.1.323_clustered_sequences_90_augmented.fasta
# 1.1.1.324_clustered_sequences_90_augmented.fasta
# 1.1.1.325_clustered_sequences_90_augmented.fasta
# 1.1.1.326_clustered_sequences_90_augmented.fasta
# 1.1.1.327_clustered_sequences_90_augmented.fasta
# 1.1.1.328_clustered_sequences_90_augmented.fasta
# 1.1.1.329_clustered_sequences_90_augmented.fasta
# 1.1.1.32_clustered_sequences_90_augmented.fasta
# 1.1.1.330_clustered_sequences_90_augmented.fasta
# 1.1.1.331_clustered_sequences_90_augmented.fasta
# 1.1.1.332_clustered_sequences_90_augmented.fasta
# 1.1.1.333_clustered_sequences_90_augmented.fasta
# 1.1.1.334_clustered_sequences_90_augmented.fasta
# 1.1.1.335_clustered_sequences_90_augmented.fasta
# 1.1.1.336_clustered_sequences_90_augmented.fasta
# 1.1.1.337_clustered_sequences_90_augmented.fasta
# 1.1.1.338_clustered_sequences_90_augmented.fasta
# 1.1.1.339_clustered_sequences_90_augmented.fasta
# 1.1.1.340_clustered_sequences_90_augmented.fasta
# 1.1.1.341_clustered_sequences_90_augmented.fasta
# 1.1.1.342_clustered_sequences_90_augmented.fasta
# 1.1.1.343_clustered_sequences_90_augmented.fasta
# 1.1.1.344_clustered_sequences_90_augmented.fasta
# 1.1.1.345_clustered_sequences_90_augmented.fasta
# 1.1.1.346_clustered_sequences_90_augmented.fasta
# 1.1.1.347_clustered_sequences_90_augmented.fasta
# 1.1.1.348_clustered_sequences_90_augmented.fasta
# 1.1.1.349_clustered_sequences_90_augmented.fasta
# 1.1.1.34_clustered_sequences_90_augmented.fasta
# 1.1.1.350_clustered_sequences_90_augmented.fasta
# 1.1.1.351_clustered_sequences_90_augmented.fasta
# 1.1.1.352_clustered_sequences_90_augmented.fasta
# 1.1.1.353_clustered_sequences_90_augmented.fasta
# 1.1.1.354_clustered_sequences_90_augmented.fasta
# 1.1.1.355_clustered_sequences_90_augmented.fasta
# 1.1.1.356_clustered_sequences_90_augmented.fasta
# 1.1.1.357_clustered_sequences_90_augmented.fasta
# 1.1.1.358_clustered_sequences_90_augmented.fasta
# 1.1.1.359_clustered_sequences_90_augmented.fasta
# 1.1.1.35_clustered_sequences_90_augmented.fasta
#   4%|▍         | 1660/37060 [00:00<00:13, 2567.62it/s]
# 1.1.1.360_clustered_sequences_90_augmented.fasta
# 1.1.1.361_clustered_sequences_90_augmented.fasta
# 1.1.1.362_clustered_sequences_90_augmented.fasta
# 1.1.1.363_clustered_sequences_90_augmented.fasta
# 1.1.1.364_clustered_sequences_90_augmented.fasta
# 1.1.1.365_clustered_sequences_90_augmented.fasta
# 1.1.1.366_clustered_sequences_90_augmented.fasta
# 1.1.1.367_clustered_sequences_90_augmented.fasta
# 1.1.1.368_clustered_sequences_90_augmented.fasta
# 1.1.1.369_clustered_sequences_90_augmented.fasta
# 1.1.1.36_clustered_sequences_90_augmented.fasta
# 1.1.1.370_clustered_sequences_90_augmented.fasta
# 1.1.1.371_clustered_sequences_90_augmented.fasta
# 1.1.1.372_clustered_sequences_90_augmented.fasta
# 1.1.1.373_clustered_sequences_90_augmented.fasta
# 1.1.1.374_clustered_sequences_90_augmented.fasta
# 1.1.1.375_clustered_sequences_90_augmented.fasta
# 1.1.1.376_clustered_sequences_90_augmented.fasta
# 1.1.1.377_clustered_sequences_90_augmented.fasta
# 1.1.1.378_clustered_sequences_90_augmented.fasta
# 1.1.1.37_clustered_sequences_90_augmented.fasta
# 1.1.1.380_clustered_sequences_90_augmented.fasta
# 1.1.1.381_clustered_sequences_90_augmented.fasta
# 1.1.1.382_clustered_sequences_90_augmented.fasta
# 1.1.1.383_clustered_sequences_90_augmented.fasta
# 1.1.1.384_clustered_sequences_90_augmented.fasta
# 1.1.1.385_clustered_sequences_90_augmented.fasta
# 1.1.1.386_clustered_sequences_90_augmented.fasta
# 1.1.1.387_clustered_sequences_90_augmented.fasta
# 1.1.1.388_clustered_sequences_90_augmented.fasta
# 1.1.1.389_clustered_sequences_90_augmented.fasta
# 1.1.1.38_clustered_sequences_90_augmented.fasta
# 1.1.1.390_clustered_sequences_90_augmented.fasta
# 1.1.1.391_clustered_sequences_90_augmented.fasta
# 1.1.1.392_clustered_sequences_90_augmented.fasta
# 1.1.1.393_clustered_sequences_90_augmented.fasta
# 1.1.1.394_clustered_sequences_90_augmented.fasta
# 1.1.1.395_clustered_sequences_90_augmented.fasta
# 1.1.1.396_clustered_sequences_90_augmented.fasta
# 1.1.1.397_clustered_sequences_90_augmented.fasta
# 1.1.1.399_clustered_sequences_90_augmented.fasta
# 1.1.1.39_clustered_sequences_90_augmented.fasta
# 1.1.1.3_clustered_sequences_90_augmented.fasta
# 1.1.1.400_clustered_sequences_90_augmented.fasta
# 1.1.1.401_clustered_sequences_90_augmented.fasta
# 1.1.1.403_clustered_sequences_90_augmented.fasta
# 1.1.1.404_clustered_sequences_90_augmented.fasta
# 1.1.1.405_clustered_sequences_90_augmented.fasta
# 1.1.1.406_clustered_sequences_90_augmented.fasta
# 1.1.1.407_clustered_sequences_90_augmented.fasta
# 1.1.1.408_clustered_sequences_90_augmented.fasta
# 1.1.1.409_clustered_sequences_90_augmented.fasta
# 1.1.1.40_clustered_sequences_90_augmented.fasta
# 1.1.1.410_clustered_sequences_90_augmented.fasta
# 1.1.1.411_clustered_sequences_90_augmented.fasta
# 1.1.1.412_clustered_sequences_90_augmented.fasta
# 1.1.1.414_clustered_sequences_90_augmented.fasta
# 1.1.1.415_clustered_sequences_90_augmented.fasta
# 1.1.1.416_clustered_sequences_90_augmented.fasta
# 1.1.1.41_clustered_sequences_90_augmented.fasta
# 1.1.1.42_clustered_sequences_90_augmented.fasta
# 1.1.1.43_clustered_sequences_90_augmented.fasta
# 1.1.1.44_clustered_sequences_90_augmented.fasta
# 1.1.1.45_clustered_sequences_90_augmented.fasta
# 1.1.1.46_clustered_sequences_90_augmented.fasta
# 1.1.1.47_clustered_sequences_90_augmented.fasta
# 1.1.1.48_clustered_sequences_90_augmented.fasta
# 1.1.1.49_clustered_sequences_90_augmented.fasta
# 1.1.1.4_clustered_sequences_90_augmented.fasta
# 1.1.1.50_clustered_sequences_90_augmented.fasta
# 1.1.1.51_clustered_sequences_90_augmented.fasta
# 1.1.1.52_clustered_sequences_90_augmented.fasta
# 1.1.1.53_clustered_sequences_90_augmented.fasta
# 1.1.1.54_clustered_sequences_90_augmented.fasta
# 1.1.1.56_clustered_sequences_90_augmented.fasta
# 1.1.1.57_clustered_sequences_90_augmented.fasta
# 1.1.1.58_clustered_sequences_90_augmented.fasta
# 1.1.1.59_clustered_sequences_90_augmented.fasta
# 1.1.1.5_clustered_sequences_90_augmented.fasta
# 1.1.1.60_clustered_sequences_90_augmented.fasta
# 1.1.1.61_clustered_sequences_90_augmented.fasta
# 1.1.1.62_clustered_sequences_90_augmented.fasta
# 1.1.1.63_clustered_sequences_90_augmented.fasta
# 1.1.1.64_clustered_sequences_90_augmented.fasta
# 1.1.1.65_clustered_sequences_90_augmented.fasta
# 1.1.1.67_clustered_sequences_90_augmented.fasta
# 1.1.1.68_clustered_sequences_90_augmented.fasta
# 1.1.1.69_clustered_sequences_90_augmented.fasta
# 1.1.1.6_clustered_sequences_90_augmented.fasta
# 1.1.1.70_clustered_sequences_90_augmented.fasta
# 1.1.1.71_clustered_sequences_90_augmented.fasta
# 1.1.1.72_clustered_sequences_90_augmented.fasta
# 1.1.1.73_clustered_sequences_90_augmented.fasta
# 1.1.1.74_clustered_sequences_90_augmented.fasta
# 1.1.1.75_clustered_sequences_90_augmented.fasta
# 1.1.1.76_clustered_sequences_90_augmented.fasta
# 1.1.1.77_clustered_sequences_90_augmented.fasta
# 1.1.1.78_clustered_sequences_90_augmented.fasta
# 1.1.1.79_clustered_sequences_90_augmented.fasta
# 1.1.1.7_clustered_sequences_90_augmented.fasta
# 1.1.1.80_clustered_sequences_90_augmented.fasta
# 1.1.1.81_clustered_sequences_90_augmented.fasta
# 1.1.1.82_clustered_sequences_90_augmented.fasta
# 1.1.1.83_clustered_sequences_90_augmented.fasta
# 1.1.1.85_clustered_sequences_90_augmented.fasta
# 1.1.1.86_clustered_sequences_90_augmented.fasta
# 1.1.1.87_clustered_sequences_90_augmented.fasta
# 1.1.1.88_clustered_sequences_90_augmented.fasta
# 1.1.1.89_clustered_sequences_90_augmented.fasta
# 1.1.1.8_clustered_sequences_90_augmented.fasta
# 1.1.1.90_clustered_sequences_90_augmented.fasta
# 1.1.1.91_clustered_sequences_90_augmented.fasta
#   7%|▋         | 2750/37060 [00:00<00:10, 3280.84it/s]
# 1.1.1.92_clustered_sequences_90_augmented.fasta
# 1.1.1.93_clustered_sequences_90_augmented.fasta
# 1.1.1.94_clustered_sequences_90_augmented.fasta
# 1.1.1.95_clustered_sequences_90_augmented.fasta
# 1.1.1.96_clustered_sequences_90_augmented.fasta
# 1.1.1.99_clustered_sequences_90_augmented.fasta
# 1.1.1.9_clustered_sequences_90_augmented.fasta
# 1.1.1.B18_clustered_sequences_90_augmented.fasta
# 1.1.1.B19_clustered_sequences_90_augmented.fasta
# 1.1.1.B20_clustered_sequences_90_augmented.fasta
# 1.1.1.B25_clustered_sequences_90_augmented.fasta
# 1.1.1.B28_clustered_sequences_90_augmented.fasta
# 1.1.1.B35_clustered_sequences_90_augmented.fasta
# 1.1.1.B38_clustered_sequences_90_augmented.fasta
# 1.1.1.B3_clustered_sequences_90_augmented.fasta
# 1.1.1.B40_clustered_sequences_90_augmented.fasta
# 1.1.1.B47_clustered_sequences_90_augmented.fasta
# 1.1.1.B4_clustered_sequences_90_augmented.fasta
# 1.1.1.B51_clustered_sequences_90_augmented.fasta
# 1.1.1.B52_clustered_sequences_90_augmented.fasta
# 1.1.1.B57_clustered_sequences_90_augmented.fasta
# 1.1.1.B58_clustered_sequences_90_augmented.fasta
# 1.1.1.B60_clustered_sequences_90_augmented.fasta
# 1.1.1.B61_clustered_sequences_90_augmented.fasta
# 1.1.1.B63_clustered_sequences_90_augmented.fasta
# 1.1.1.B64_clustered_sequences_90_augmented.fasta
# 1.1.1.B65_clustered_sequences_90_augmented.fasta
# 1.1.2.1_clustered_sequences_90_augmented.fasta
# 1.1.2.2_clustered_sequences_90_augmented.fasta
# 1.1.2.3_clustered_sequences_90_augmented.fasta
# 1.1.2.4_clustered_sequences_90_augmented.fasta
# 1.1.2.5_clustered_sequences_90_augmented.fasta
# 1.1.2.6_clustered_sequences_90_augmented.fasta
# 1.1.2.7_clustered_sequences_90_augmented.fasta
# 1.1.2.8_clustered_sequences_90_augmented.fasta
# 1.1.2.9_clustered_sequences_90_augmented.fasta
# 1.1.2.B2_clustered_sequences_90_augmented.fasta
# 1.1.2.B3_clustered_sequences_90_augmented.fasta
# 1.1.2.B5_clustered_sequences_90_augmented.fasta
# 1.1.3.10_clustered_sequences_90_augmented.fasta
# 1.1.3.11_clustered_sequences_90_augmented.fasta
# 1.1.3.12_clustered_sequences_90_augmented.fasta
# 1.1.3.13_clustered_sequences_90_augmented.fasta
# 1.1.3.14_clustered_sequences_90_augmented.fasta
# 1.1.3.15_clustered_sequences_90_augmented.fasta
# 1.1.3.16_clustered_sequences_90_augmented.fasta
# 1.1.3.17_clustered_sequences_90_augmented.fasta
# 1.1.3.1_clustered_sequences_90_augmented.fasta
# 1.1.3.20_clustered_sequences_90_augmented.fasta
# 1.1.3.21_clustered_sequences_90_augmented.fasta
# 1.1.3.22_clustered_sequences_90_augmented.fasta
# 1.1.3.24_clustered_sequences_90_augmented.fasta
# 1.1.3.25_clustered_sequences_90_augmented.fasta
# 1.1.3.26_clustered_sequences_90_augmented.fasta
# 1.1.3.29_clustered_sequences_90_augmented.fasta
# 1.1.3.2_clustered_sequences_90_augmented.fasta
# 1.1.3.30_clustered_sequences_90_augmented.fasta
# 1.1.3.31_clustered_sequences_90_augmented.fasta
# 1.1.3.32_clustered_sequences_90_augmented.fasta
# 1.1.3.33_clustered_sequences_90_augmented.fasta
# 1.1.3.34_clustered_sequences_90_augmented.fasta
# 1.1.3.35_clustered_sequences_90_augmented.fasta
# 1.1.3.36_clustered_sequences_90_augmented.fasta
# 1.1.3.37_clustered_sequences_90_augmented.fasta
# 1.1.3.38_clustered_sequences_90_augmented.fasta
# 1.1.3.39_clustered_sequences_90_augmented.fasta
# 1.1.3.3_clustered_sequences_90_augmented.fasta
# 1.1.3.40_clustered_sequences_90_augmented.fasta
# 1.1.3.41_clustered_sequences_90_augmented.fasta
# 1.1.3.42_clustered_sequences_90_augmented.fasta
# 1.1.3.43_clustered_sequences_90_augmented.fasta
# 1.1.3.44_clustered_sequences_90_augmented.fasta
# 1.1.3.45_clustered_sequences_90_augmented.fasta
# 1.1.3.46_clustered_sequences_90_augmented.fasta
# 1.1.3.47_clustered_sequences_90_augmented.fasta
# 1.1.3.48_clustered_sequences_90_augmented.fasta
# 1.1.3.4_clustered_sequences_90_augmented.fasta
# 1.1.3.5_clustered_sequences_90_augmented.fasta
# 1.1.3.6_clustered_sequences_90_augmented.fasta
# 1.1.3.7_clustered_sequences_90_augmented.fasta
# 1.1.3.8_clustered_sequences_90_augmented.fasta
# 1.1.3.9_clustered_sequences_90_augmented.fasta
# 1.1.3.B4_clustered_sequences_90_augmented.fasta
# 1.1.4.1_clustered_sequences_90_augmented.fasta
# 1.1.4.2_clustered_sequences_90_augmented.fasta
# 1.1.4.B1_clustered_sequences_90_augmented.fasta
# 1.1.5.10_clustered_sequences_90_augmented.fasta
# 1.1.5.11_clustered_sequences_90_augmented.fasta
# 1.1.5.12_clustered_sequences_90_augmented.fasta
# 1.1.5.1_clustered_sequences_90_augmented.fasta
# 1.1.5.2_clustered_sequences_90_augmented.fasta
# 1.1.5.3_clustered_sequences_90_augmented.fasta
# 1.1.5.4_clustered_sequences_90_augmented.fasta
# 1.1.5.5_clustered_sequences_90_augmented.fasta
# 1.1.5.6_clustered_sequences_90_augmented.fasta
# 1.1.5.7_clustered_sequences_90_augmented.fasta
# 1.1.5.8_clustered_sequences_90_augmented.fasta
# 1.1.5.9_clustered_sequences_90_augmented.fasta
# 1.1.5.B1_clustered_sequences_90_augmented.fasta
# 1.1.5.B3_clustered_sequences_90_augmented.fasta
# 1.1.9.1_clustered_sequences_90_augmented.fasta
# 1.1.98.1_clustered_sequences_90_augmented.fasta
# 1.1.98.2_clustered_sequences_90_augmented.fasta
# 1.1.98.3_clustered_sequences_90_augmented.fasta
# 1.1.98.4_clustered_sequences_90_augmented.fasta
# 1.1.98.5_clustered_sequences_90_augmented.fasta
# 1.1.98.6_clustered_sequences_90_augmented.fasta
# 1.1.99.10_clustered_sequences_90_augmented.fasta
# 1.1.99.11_clustered_sequences_90_augmented.fasta
# 1.1.99.12_clustered_sequences_90_augmented.fasta
# 1.1.99.13_clustered_sequences_90_augmented.fasta
# 1.1.99.14_clustered_sequences_90_augmented.fasta
# 1.1.99.15_clustered_sequences_90_augmented.fasta
# 1.1.99.16_clustered_sequences_90_augmented.fasta
# 1.1.99.17_clustered_sequences_90_augmented.fasta
# 1.1.99.18_clustered_sequences_90_augmented.fasta
# 1.1.99.19_clustered_sequences_90_augmented.fasta
# 1.1.99.1_clustered_sequences_90_augmented.fasta
# 1.1.99.20_clustered_sequences_90_augmented.fasta
# 1.1.99.21_clustered_sequences_90_augmented.fasta
# 1.1.99.22_clustered_sequences_90_augmented.fasta
# 1.1.99.23_clustered_sequences_90_augmented.fasta
# 1.1.99.24_clustered_sequences_90_augmented.fasta
# 1.1.99.25_clustered_sequences_90_augmented.fasta
# 1.1.99.27_clustered_sequences_90_augmented.fasta
# 1.1.99.28_clustered_sequences_90_augmented.fasta
# 1.1.99.29_clustered_sequences_90_augmented.fasta
# 1.1.99.2_clustered_sequences_90_augmented.fasta
# 1.1.99.30_clustered_sequences_90_augmented.fasta
# 1.1.99.31_clustered_sequences_90_augmented.fasta
# 1.1.99.32_clustered_sequences_90_augmented.fasta
# 1.1.99.33_clustered_sequences_90_augmented.fasta
# 1.1.99.34_clustered_sequences_90_augmented.fasta
# 1.1.99.35_clustered_sequences_90_augmented.fasta
# 1.1.99.36_clustered_sequences_90_augmented.fasta
# 1.1.99.37_clustered_sequences_90_augmented.fasta
# 1.1.99.38_clustered_sequences_90_augmented.fasta
# 1.1.99.39_clustered_sequences_90_augmented.fasta
# 1.1.99.3_clustered_sequences_90_augmented.fasta
# 1.1.99.40_clustered_sequences_90_augmented.fasta
# 1.1.99.41_clustered_sequences_90_augmented.fasta
# 1.1.99.42_clustered_sequences_90_augmented.fasta
# 1.1.99.4_clustered_sequences_90_augmented.fasta
# 1.1.99.5_clustered_sequences_90_augmented.fasta
# 1.1.99.6_clustered_sequences_90_augmented.fasta
# 1.1.99.8_clustered_sequences_90_augmented.fasta
# 1.1.99.9_clustered_sequences_90_augmented.fasta
# 1.1.99.B10_clustered_sequences_90_augmented.fasta
# 1.1.99.B1_clustered_sequences_90_augmented.fasta
# 1.1.99.B3_clustered_sequences_90_augmented.fasta
# 1.1.99.B6_clustered_sequences_90_augmented.fasta
# 1.1.99.B7_clustered_sequences_90_augmented.fasta
# 1.1.99.B9_clustered_sequences_90_augmented.fasta
# 1.10.1.1_clustered_sequences_90_augmented.fasta
# 1.10.2.2_clustered_sequences_90_augmented.fasta
# 1.10.3.10_clustered_sequences_90_augmented.fasta
# 1.10.3.11_clustered_sequences_90_augmented.fasta
# 1.10.3.12_clustered_sequences_90_augmented.fasta
# 1.10.3.13_clustered_sequences_90_augmented.fasta
# 1.10.3.14_clustered_sequences_90_augmented.fasta
# 1.10.3.15_clustered_sequences_90_augmented.fasta
# 1.10.3.16_clustered_sequences_90_augmented.fasta
# 1.10.3.1_clustered_sequences_90_augmented.fasta
# 1.10.3.2_clustered_sequences_90_augmented.fasta
# 1.10.3.3_clustered_sequences_90_augmented.fasta
# 1.10.3.4_clustered_sequences_90_augmented.fasta
# 1.10.3.5_clustered_sequences_90_augmented.fasta
# 1.10.3.7_clustered_sequences_90_augmented.fasta
# 1.10.3.8_clustered_sequences_90_augmented.fasta
# 1.10.3.9_clustered_sequences_90_augmented.fasta
# 1.10.5.1_clustered_sequences_90_augmented.fasta
# 1.10.9.1_clustered_sequences_90_augmented.fasta
# 1.10.99.1_clustered_sequences_90_augmented.fasta
# 1.10.99.2_clustered_sequences_90_augmented.fasta
# 1.10.99.3_clustered_sequences_90_augmented.fasta
# 1.11.1.10_clustered_sequences_90_augmented.fasta
# 1.11.1.11_clustered_sequences_90_augmented.fasta
# 1.11.1.12_clustered_sequences_90_augmented.fasta
# 1.11.1.13_clustered_sequences_90_augmented.fasta
# 1.11.1.14_clustered_sequences_90_augmented.fasta
# 1.11.1.15_clustered_sequences_90_augmented.fasta
# 1.11.1.16_clustered_sequences_90_augmented.fasta
# 1.11.1.17_clustered_sequences_90_augmented.fasta
# 1.11.1.18_clustered_sequences_90_augmented.fasta
# 1.11.1.19_clustered_sequences_90_augmented.fasta
# 1.11.1.1_clustered_sequences_90_augmented.fasta
# 1.11.1.20_clustered_sequences_90_augmented.fasta
# 1.11.1.21_clustered_sequences_90_augmented.fasta
# 1.11.1.22_clustered_sequences_90_augmented.fasta
# 1.11.1.23_clustered_sequences_90_augmented.fasta
# 1.11.1.3_clustered_sequences_90_augmented.fasta
# 1.11.1.4_clustered_sequences_90_augmented.fasta
# 1.11.1.5_clustered_sequences_90_augmented.fasta
# 1.11.1.6_clustered_sequences_90_augmented.fasta
#  12%|█▏        | 4265/37060 [00:01<00:08, 4004.94it/s]
# 1.11.1.7_clustered_sequences_90_augmented.fasta
# 1.11.1.8_clustered_sequences_90_augmented.fasta
# 1.11.1.9_clustered_sequences_90_augmented.fasta
# 1.11.1.B10_clustered_sequences_90_augmented.fasta
# 1.11.1.B2_clustered_sequences_90_augmented.fasta
# 1.11.1.B6_clustered_sequences_90_augmented.fasta
# 1.11.1.B7_clustered_sequences_90_augmented.fasta
# 1.11.1.B8_clustered_sequences_90_augmented.fasta
# 1.11.2.1_clustered_sequences_90_augmented.fasta
# 1.11.2.2_clustered_sequences_90_augmented.fasta
# 1.11.2.3_clustered_sequences_90_augmented.fasta
# 1.11.2.4_clustered_sequences_90_augmented.fasta
# 1.11.2.5_clustered_sequences_90_augmented.fasta
# 1.12.1.1_clustered_sequences_90_augmented.fasta
# 1.12.1.2_clustered_sequences_90_augmented.fasta
# 1.12.1.3_clustered_sequences_90_augmented.fasta
# 1.12.1.4_clustered_sequences_90_augmented.fasta
# 1.12.1.5_clustered_sequences_90_augmented.fasta
# 1.12.2.1_clustered_sequences_90_augmented.fasta
# 1.12.5.1_clustered_sequences_90_augmented.fasta
# 1.12.7.1_clustered_sequences_90_augmented.fasta
# 1.12.7.2_clustered_sequences_90_augmented.fasta
# 1.12.98.1_clustered_sequences_90_augmented.fasta
# 1.12.98.2_clustered_sequences_90_augmented.fasta
# 1.12.98.3_clustered_sequences_90_augmented.fasta
# 1.12.98.4_clustered_sequences_90_augmented.fasta
# 1.12.98.B1_clustered_sequences_90_augmented.fasta
# 1.12.99.1_clustered_sequences_90_augmented.fasta
# 1.12.99.2_clustered_sequences_90_augmented.fasta
# 1.12.99.3_clustered_sequences_90_augmented.fasta
# 1.12.99.4_clustered_sequences_90_augmented.fasta
# 1.12.99.5_clustered_sequences_90_augmented.fasta
# 1.12.99.6_clustered_sequences_90_augmented.fasta
# 1.13.11.10_clustered_sequences_90_augmented.fasta
# 1.13.11.11_clustered_sequences_90_augmented.fasta
# 1.13.11.12_clustered_sequences_90_augmented.fasta
# 1.13.11.13_clustered_sequences_90_augmented.fasta
# 1.13.11.14_clustered_sequences_90_augmented.fasta
# 1.13.11.15_clustered_sequences_90_augmented.fasta
# 1.13.11.16_clustered_sequences_90_augmented.fasta
# 1.13.11.17_clustered_sequences_90_augmented.fasta
# 1.13.11.18_clustered_sequences_90_augmented.fasta
# 1.13.11.19_clustered_sequences_90_augmented.fasta
# 1.13.11.1_clustered_sequences_90_augmented.fasta
# 1.13.11.20_clustered_sequences_90_augmented.fasta
# 1.13.11.21_clustered_sequences_90_augmented.fasta
# 1.13.11.23_clustered_sequences_90_augmented.fasta
# 1.13.11.24_clustered_sequences_90_augmented.fasta
# 1.13.11.25_clustered_sequences_90_augmented.fasta
# 1.13.11.27_clustered_sequences_90_augmented.fasta
# 1.13.11.28_clustered_sequences_90_augmented.fasta
# 1.13.11.29_clustered_sequences_90_augmented.fasta
# 1.13.11.2_clustered_sequences_90_augmented.fasta
# 1.13.11.31_clustered_sequences_90_augmented.fasta
# 1.13.11.32_clustered_sequences_90_augmented.fasta
# 1.13.11.33_clustered_sequences_90_augmented.fasta
# 1.13.11.34_clustered_sequences_90_augmented.fasta
# 1.13.11.35_clustered_sequences_90_augmented.fasta
# 1.13.11.37_clustered_sequences_90_augmented.fasta
# 1.13.11.38_clustered_sequences_90_augmented.fasta
# 1.13.11.39_clustered_sequences_90_augmented.fasta
# 1.13.11.3_clustered_sequences_90_augmented.fasta
# 1.13.11.40_clustered_sequences_90_augmented.fasta
# 1.13.11.41_clustered_sequences_90_augmented.fasta
# 1.13.11.42_clustered_sequences_90_augmented.fasta
# 1.13.11.43_clustered_sequences_90_augmented.fasta
# 1.13.11.44_clustered_sequences_90_augmented.fasta
# 1.13.11.45_clustered_sequences_90_augmented.fasta
# 1.13.11.46_clustered_sequences_90_augmented.fasta
# 1.13.11.47_clustered_sequences_90_augmented.fasta
# 1.13.11.48_clustered_sequences_90_augmented.fasta
# 1.13.11.49_clustered_sequences_90_augmented.fasta
# 1.13.11.4_clustered_sequences_90_augmented.fasta
# 1.13.11.50_clustered_sequences_90_augmented.fasta
# 1.13.11.51_clustered_sequences_90_augmented.fasta
# 1.13.11.52_clustered_sequences_90_augmented.fasta
# 1.13.11.53_clustered_sequences_90_augmented.fasta
# 1.13.11.54_clustered_sequences_90_augmented.fasta
# 1.13.11.55_clustered_sequences_90_augmented.fasta
# 1.13.11.56_clustered_sequences_90_augmented.fasta
# 1.13.11.57_clustered_sequences_90_augmented.fasta
# 1.13.11.58_clustered_sequences_90_augmented.fasta
# 1.13.11.59_clustered_sequences_90_augmented.fasta
# 1.13.11.5_clustered_sequences_90_augmented.fasta
# 1.13.11.60_clustered_sequences_90_augmented.fasta
# 1.13.11.61_clustered_sequences_90_augmented.fasta
# 1.13.11.62_clustered_sequences_90_augmented.fasta
# 1.13.11.63_clustered_sequences_90_augmented.fasta
# 1.13.11.64_clustered_sequences_90_augmented.fasta
# 1.13.11.65_clustered_sequences_90_augmented.fasta
# 1.13.11.66_clustered_sequences_90_augmented.fasta
# 1.13.11.67_clustered_sequences_90_augmented.fasta
# 1.13.11.68_clustered_sequences_90_augmented.fasta
# 1.13.11.69_clustered_sequences_90_augmented.fasta
# 1.13.11.6_clustered_sequences_90_augmented.fasta
# 1.13.11.70_clustered_sequences_90_augmented.fasta
# 1.13.11.71_clustered_sequences_90_augmented.fasta
# 1.13.11.72_clustered_sequences_90_augmented.fasta
# 1.13.11.73_clustered_sequences_90_augmented.fasta
# 1.13.11.74_clustered_sequences_90_augmented.fasta
# 1.13.11.75_clustered_sequences_90_augmented.fasta
# 1.13.11.76_clustered_sequences_90_augmented.fasta
# 1.13.11.77_clustered_sequences_90_augmented.fasta
# 1.13.11.78_clustered_sequences_90_augmented.fasta
# 1.13.11.79_clustered_sequences_90_augmented.fasta
# 1.13.11.7_clustered_sequences_90_augmented.fasta
# 1.13.11.80_clustered_sequences_90_augmented.fasta
# 1.13.11.81_clustered_sequences_90_augmented.fasta
# 1.13.11.82_clustered_sequences_90_augmented.fasta
# 1.13.11.83_clustered_sequences_90_augmented.fasta
# 1.13.11.84_clustered_sequences_90_augmented.fasta
# 1.13.11.85_clustered_sequences_90_augmented.fasta
# 1.13.11.86_clustered_sequences_90_augmented.fasta
# 1.13.11.87_clustered_sequences_90_augmented.fasta
# 1.13.11.8_clustered_sequences_90_augmented.fasta
# 1.13.11.9_clustered_sequences_90_augmented.fasta
# 1.13.11.B1_clustered_sequences_90_augmented.fasta
# 1.13.11.B6_clustered_sequences_90_augmented.fasta
# 1.13.12.10_clustered_sequences_90_augmented.fasta
# 1.13.12.11_clustered_sequences_90_augmented.fasta
# 1.13.12.12_clustered_sequences_90_augmented.fasta
# 1.13.12.13_clustered_sequences_90_augmented.fasta
# 1.13.12.14_clustered_sequences_90_augmented.fasta
# 1.13.12.15_clustered_sequences_90_augmented.fasta
# 1.13.12.16_clustered_sequences_90_augmented.fasta
# 1.13.12.17_clustered_sequences_90_augmented.fasta
# 1.13.12.18_clustered_sequences_90_augmented.fasta
# 1.13.12.19_clustered_sequences_90_augmented.fasta
# 1.13.12.20_clustered_sequences_90_augmented.fasta
# 1.13.12.21_clustered_sequences_90_augmented.fasta
# 1.13.12.22_clustered_sequences_90_augmented.fasta
# 1.13.12.23_clustered_sequences_90_augmented.fasta
# 1.13.12.24_clustered_sequences_90_augmented.fasta
# 1.13.12.2_clustered_sequences_90_augmented.fasta
# 1.13.12.3_clustered_sequences_90_augmented.fasta
# 1.13.12.4_clustered_sequences_90_augmented.fasta
# 1.13.12.5_clustered_sequences_90_augmented.fasta
# 1.13.12.6_clustered_sequences_90_augmented.fasta
# 1.13.12.7_clustered_sequences_90_augmented.fasta
# 1.13.12.9_clustered_sequences_90_augmented.fasta
# 1.13.99.1_clustered_sequences_90_augmented.fasta
# 1.13.99.2_clustered_sequences_90_augmented.fasta
# 1.13.99.4_clustered_sequences_90_augmented.fasta
# 1.13.99.5_clustered_sequences_90_augmented.fasta
# 1.13.99.B1_clustered_sequences_90_augmented.fasta
# 1.14.11.11_clustered_sequences_90_augmented.fasta
# 1.14.11.12_clustered_sequences_90_augmented.fasta
# 1.14.11.13_clustered_sequences_90_augmented.fasta
# 1.14.11.14_clustered_sequences_90_augmented.fasta
# 1.14.11.15_clustered_sequences_90_augmented.fasta
# 1.14.11.16_clustered_sequences_90_augmented.fasta
# 1.14.11.17_clustered_sequences_90_augmented.fasta
# 1.14.11.18_clustered_sequences_90_augmented.fasta
# 1.14.11.19_clustered_sequences_90_augmented.fasta
# 1.14.11.1_clustered_sequences_90_augmented.fasta
# 1.14.11.20_clustered_sequences_90_augmented.fasta
# 1.14.11.21_clustered_sequences_90_augmented.fasta
# 1.14.11.22_clustered_sequences_90_augmented.fasta
# 1.14.11.23_clustered_sequences_90_augmented.fasta
# 1.14.11.24_clustered_sequences_90_augmented.fasta
# 1.14.11.25_clustered_sequences_90_augmented.fasta
# 1.14.11.26_clustered_sequences_90_augmented.fasta
# 1.14.11.27_clustered_sequences_90_augmented.fasta
# 1.14.11.28_clustered_sequences_90_augmented.fasta
# 1.14.11.29_clustered_sequences_90_augmented.fasta
# 1.14.11.2_clustered_sequences_90_augmented.fasta
# 1.14.11.30_clustered_sequences_90_augmented.fasta
# 1.14.11.31_clustered_sequences_90_augmented.fasta
# 1.14.11.32_clustered_sequences_90_augmented.fasta
# 1.14.11.33_clustered_sequences_90_augmented.fasta
# 1.14.11.34_clustered_sequences_90_augmented.fasta
# 1.14.11.35_clustered_sequences_90_augmented.fasta
# 1.14.11.36_clustered_sequences_90_augmented.fasta
# 1.14.11.37_clustered_sequences_90_augmented.fasta
# 1.14.11.38_clustered_sequences_90_augmented.fasta
# 1.14.11.39_clustered_sequences_90_augmented.fasta
# 1.14.11.3_clustered_sequences_90_augmented.fasta
# 1.14.11.40_clustered_sequences_90_augmented.fasta
# 1.14.11.41_clustered_sequences_90_augmented.fasta
# 1.14.11.42_clustered_sequences_90_augmented.fasta
# 1.14.11.43_clustered_sequences_90_augmented.fasta
# 1.14.11.44_clustered_sequences_90_augmented.fasta
# 1.14.11.45_clustered_sequences_90_augmented.fasta
# 1.14.11.47_clustered_sequences_90_augmented.fasta
# 1.14.11.48_clustered_sequences_90_augmented.fasta
# 1.14.11.4_clustered_sequences_90_augmented.fasta
# 1.14.11.50_clustered_sequences_90_augmented.fasta
# 1.14.11.51_clustered_sequences_90_augmented.fasta
# 1.14.11.52_clustered_sequences_90_augmented.fasta
# 1.14.11.53_clustered_sequences_90_augmented.fasta
# 1.14.11.54_clustered_sequences_90_augmented.fasta
# 1.14.11.55_clustered_sequences_90_augmented.fasta
# 1.14.11.56_clustered_sequences_90_augmented.fasta
# 1.14.11.57_clustered_sequences_90_augmented.fasta
# 1.14.11.58_clustered_sequences_90_augmented.fasta
# 1.14.11.59_clustered_sequences_90_augmented.fasta
# 1.14.11.5_clustered_sequences_90_augmented.fasta
# 1.14.11.60_clustered_sequences_90_augmented.fasta
# 1.14.11.6_clustered_sequences_90_augmented.fasta
# 1.14.11.7_clustered_sequences_90_augmented.fasta
# 1.14.11.8_clustered_sequences_90_augmented.fasta
# 1.14.11.9_clustered_sequences_90_augmented.fasta
# 1.14.11.B11_clustered_sequences_90_augmented.fasta
# 1.14.11.B15_clustered_sequences_90_augmented.fasta
# 1.14.11.B16_clustered_sequences_90_augmented.fasta
# 1.14.11.B17_clustered_sequences_90_augmented.fasta
# 1.14.11.B18_clustered_sequences_90_augmented.fasta
# 1.14.11.B1_clustered_sequences_90_augmented.fasta
# 1.14.11.B2_clustered_sequences_90_augmented.fasta
# 1.14.11.B3_clustered_sequences_90_augmented.fasta
# 1.14.12.10_clustered_sequences_90_augmented.fasta
# 1.14.12.11_clustered_sequences_90_augmented.fasta
# 1.14.12.12_clustered_sequences_90_augmented.fasta
# 1.14.12.13_clustered_sequences_90_augmented.fasta
# 1.14.12.14_clustered_sequences_90_augmented.fasta
# 1.14.12.15_clustered_sequences_90_augmented.fasta
# 1.14.12.16_clustered_sequences_90_augmented.fasta
# 1.14.12.17_clustered_sequences_90_augmented.fasta
# 1.14.12.18_clustered_sequences_90_augmented.fasta
# 1.14.12.19_clustered_sequences_90_augmented.fasta
# 1.14.12.1_clustered_sequences_90_augmented.fasta
# 1.14.12.20_clustered_sequences_90_augmented.fasta
# 1.14.12.21_clustered_sequences_90_augmented.fasta
# 1.14.12.22_clustered_sequences_90_augmented.fasta
# 1.14.12.23_clustered_sequences_90_augmented.fasta
# 1.14.12.24_clustered_sequences_90_augmented.fasta
# 1.14.12.25_clustered_sequences_90_augmented.fasta
# 1.14.12.26_clustered_sequences_90_augmented.fasta
# 1.14.12.2_clustered_sequences_90_augmented.fasta
# 1.14.12.3_clustered_sequences_90_augmented.fasta
# 1.14.12.4_clustered_sequences_90_augmented.fasta
# 1.14.12.5_clustered_sequences_90_augmented.fasta
# 1.14.12.6_clustered_sequences_90_augmented.fasta
# 1.14.12.7_clustered_sequences_90_augmented.fasta
# 1.14.12.8_clustered_sequences_90_augmented.fasta
# 1.14.12.9_clustered_sequences_90_augmented.fasta
# 1.14.13.100_clustered_sequences_90_augmented.fasta
# 1.14.13.101_clustered_sequences_90_augmented.fasta
# 1.14.13.102_clustered_sequences_90_augmented.fasta
# 1.14.13.103_clustered_sequences_90_augmented.fasta
# 1.14.13.104_clustered_sequences_90_augmented.fasta
# 1.14.13.105_clustered_sequences_90_augmented.fasta
# 1.14.13.106_clustered_sequences_90_augmented.fasta
# 1.14.13.107_clustered_sequences_90_augmented.fasta
# 1.14.13.108_clustered_sequences_90_augmented.fasta
# 1.14.13.109_clustered_sequences_90_augmented.fasta
# 1.14.13.10_clustered_sequences_90_augmented.fasta
# 1.14.13.110_clustered_sequences_90_augmented.fasta
# 1.14.13.111_clustered_sequences_90_augmented.fasta
# 1.14.13.112_clustered_sequences_90_augmented.fasta
# 1.14.13.113_clustered_sequences_90_augmented.fasta
# 1.14.13.114_clustered_sequences_90_augmented.fasta
# 1.14.13.115_clustered_sequences_90_augmented.fasta
# 1.14.13.116_clustered_sequences_90_augmented.fasta
# 1.14.13.117_clustered_sequences_90_augmented.fasta
# 1.14.13.118_clustered_sequences_90_augmented.fasta
# 1.14.13.119_clustered_sequences_90_augmented.fasta
# 1.14.13.11_clustered_sequences_90_augmented.fasta
# 1.14.13.120_clustered_sequences_90_augmented.fasta
# 1.14.13.121_clustered_sequences_90_augmented.fasta
# 1.14.13.122_clustered_sequences_90_augmented.fasta
# 1.14.13.123_clustered_sequences_90_augmented.fasta
# 1.14.13.124_clustered_sequences_90_augmented.fasta
# 1.14.13.125_clustered_sequences_90_augmented.fasta
# 1.14.13.126_clustered_sequences_90_augmented.fasta
# 1.14.13.127_clustered_sequences_90_augmented.fasta
# 1.14.13.128_clustered_sequences_90_augmented.fasta
# 1.14.13.129_clustered_sequences_90_augmented.fasta
# 1.14.13.12_clustered_sequences_90_augmented.fasta
# 1.14.13.130_clustered_sequences_90_augmented.fasta
# 1.14.13.131_clustered_sequences_90_augmented.fasta
# 1.14.13.132_clustered_sequences_90_augmented.fasta
# 1.14.13.133_clustered_sequences_90_augmented.fasta
# 1.14.13.134_clustered_sequences_90_augmented.fasta
# 1.14.13.135_clustered_sequences_90_augmented.fasta
# 1.14.13.136_clustered_sequences_90_augmented.fasta
# 1.14.13.137_clustered_sequences_90_augmented.fasta
# 1.14.13.138_clustered_sequences_90_augmented.fasta
# 1.14.13.139_clustered_sequences_90_augmented.fasta
# 1.14.13.13_clustered_sequences_90_augmented.fasta
# 1.14.13.140_clustered_sequences_90_augmented.fasta
# 1.14.13.141_clustered_sequences_90_augmented.fasta
# 1.14.13.142_clustered_sequences_90_augmented.fasta
# 1.14.13.143_clustered_sequences_90_augmented.fasta
# 1.14.13.144_clustered_sequences_90_augmented.fasta
# 1.14.13.145_clustered_sequences_90_augmented.fasta
# 1.14.13.146_clustered_sequences_90_augmented.fasta
# 1.14.13.147_clustered_sequences_90_augmented.fasta
# 1.14.13.148_clustered_sequences_90_augmented.fasta
# 1.14.13.149_clustered_sequences_90_augmented.fasta
# 1.14.13.14_clustered_sequences_90_augmented.fasta
# 1.14.13.150_clustered_sequences_90_augmented.fasta
# 1.14.13.151_clustered_sequences_90_augmented.fasta
# 1.14.13.152_clustered_sequences_90_augmented.fasta
# 1.14.13.154_clustered_sequences_90_augmented.fasta
# 1.14.13.156_clustered_sequences_90_augmented.fasta
# 1.14.13.157_clustered_sequences_90_augmented.fasta
# 1.14.13.158_clustered_sequences_90_augmented.fasta
# 1.14.13.159_clustered_sequences_90_augmented.fasta
# 1.14.13.15_clustered_sequences_90_augmented.fasta
# 1.14.13.160_clustered_sequences_90_augmented.fasta
# 1.14.13.161_clustered_sequences_90_augmented.fasta
# 1.14.13.162_clustered_sequences_90_augmented.fasta
# 1.14.13.163_clustered_sequences_90_augmented.fasta
# 1.14.13.166_clustered_sequences_90_augmented.fasta
# 1.14.13.167_clustered_sequences_90_augmented.fasta
# 1.14.13.168_clustered_sequences_90_augmented.fasta
# 1.14.13.169_clustered_sequences_90_augmented.fasta
# 1.14.13.16_clustered_sequences_90_augmented.fasta
# 1.14.13.170_clustered_sequences_90_augmented.fasta
# 1.14.13.171_clustered_sequences_90_augmented.fasta
# 1.14.13.172_clustered_sequences_90_augmented.fasta
# 1.14.13.173_clustered_sequences_90_augmented.fasta
# 1.14.13.174_clustered_sequences_90_augmented.fasta
# 1.14.13.175_clustered_sequences_90_augmented.fasta
# 1.14.13.176_clustered_sequences_90_augmented.fasta
# 1.14.13.177_clustered_sequences_90_augmented.fasta
# 1.14.13.178_clustered_sequences_90_augmented.fasta
# 1.14.13.179_clustered_sequences_90_augmented.fasta
# 1.14.13.17_clustered_sequences_90_augmented.fasta
# 1.14.13.180_clustered_sequences_90_augmented.fasta
# 1.14.13.181_clustered_sequences_90_augmented.fasta
# 1.14.13.182_clustered_sequences_90_augmented.fasta
# 1.14.13.183_clustered_sequences_90_augmented.fasta
# 1.14.13.184_clustered_sequences_90_augmented.fasta
# 1.14.13.185_clustered_sequences_90_augmented.fasta
# 1.14.13.186_clustered_sequences_90_augmented.fasta
# 1.14.13.187_clustered_sequences_90_augmented.fasta
# 1.14.13.188_clustered_sequences_90_augmented.fasta
# 1.14.13.189_clustered_sequences_90_augmented.fasta
# 1.14.13.18_clustered_sequences_90_augmented.fasta
# 1.14.13.190_clustered_sequences_90_augmented.fasta
# 1.14.13.191_clustered_sequences_90_augmented.fasta
# 1.14.13.192_clustered_sequences_90_augmented.fasta
# 1.14.13.193_clustered_sequences_90_augmented.fasta
# 1.14.13.194_clustered_sequences_90_augmented.fasta
# 1.14.13.195_clustered_sequences_90_augmented.fasta
# 1.14.13.196_clustered_sequences_90_augmented.fasta
# 1.14.13.197_clustered_sequences_90_augmented.fasta
# 1.14.13.198_clustered_sequences_90_augmented.fasta
# 1.14.13.199_clustered_sequences_90_augmented.fasta
# 1.14.13.19_clustered_sequences_90_augmented.fasta
# 1.14.13.1_clustered_sequences_90_augmented.fasta
# 1.14.13.200_clustered_sequences_90_augmented.fasta
# 1.14.13.201_clustered_sequences_90_augmented.fasta
# 1.14.13.202_clustered_sequences_90_augmented.fasta
# 1.14.13.203_clustered_sequences_90_augmented.fasta
# 1.14.13.204_clustered_sequences_90_augmented.fasta
# 1.14.13.205_clustered_sequences_90_augmented.fasta
# 1.14.13.206_clustered_sequences_90_augmented.fasta
# 1.14.13.207_clustered_sequences_90_augmented.fasta
# 1.14.13.208_clustered_sequences_90_augmented.fasta
# 1.14.13.209_clustered_sequences_90_augmented.fasta
# 1.14.13.20_clustered_sequences_90_augmented.fasta
# 1.14.13.210_clustered_sequences_90_augmented.fasta
# 1.14.13.211_clustered_sequences_90_augmented.fasta
# 1.14.13.212_clustered_sequences_90_augmented.fasta
# 1.14.13.213_clustered_sequences_90_augmented.fasta
# 1.14.13.215_clustered_sequences_90_augmented.fasta
# 1.14.13.216_clustered_sequences_90_augmented.fasta
# 1.14.13.217_clustered_sequences_90_augmented.fasta
# 1.14.13.218_clustered_sequences_90_augmented.fasta
# 1.14.13.219_clustered_sequences_90_augmented.fasta
# 1.14.13.21_clustered_sequences_90_augmented.fasta
# 1.14.13.220_clustered_sequences_90_augmented.fasta
# 1.14.13.221_clustered_sequences_90_augmented.fasta
# 1.14.13.222_clustered_sequences_90_augmented.fasta
# 1.14.13.223_clustered_sequences_90_augmented.fasta
# 1.14.13.224_clustered_sequences_90_augmented.fasta
# 1.14.13.225_clustered_sequences_90_augmented.fasta
# 1.14.13.226_clustered_sequences_90_augmented.fasta
# 1.14.13.227_clustered_sequences_90_augmented.fasta
# 1.14.13.228_clustered_sequences_90_augmented.fasta
# 1.14.13.229_clustered_sequences_90_augmented.fasta
# 1.14.13.22_clustered_sequences_90_augmented.fasta
# 1.14.13.230_clustered_sequences_90_augmented.fasta
# 1.14.13.231_clustered_sequences_90_augmented.fasta
# 1.14.13.232_clustered_sequences_90_augmented.fasta
# 1.14.13.233_clustered_sequences_90_augmented.fasta
# 1.14.13.234_clustered_sequences_90_augmented.fasta
# 1.14.13.235_clustered_sequences_90_augmented.fasta
# 1.14.13.236_clustered_sequences_90_augmented.fasta
# 1.14.13.237_clustered_sequences_90_augmented.fasta
# 1.14.13.238_clustered_sequences_90_augmented.fasta
# 1.14.13.23_clustered_sequences_90_augmented.fasta
# 1.14.13.240_clustered_sequences_90_augmented.fasta
# 1.14.13.241_clustered_sequences_90_augmented.fasta
# 1.14.13.242_clustered_sequences_90_augmented.fasta
# 1.14.13.24_clustered_sequences_90_augmented.fasta
# 1.14.13.25_clustered_sequences_90_augmented.fasta
# 1.14.13.26_clustered_sequences_90_augmented.fasta
# 1.14.13.27_clustered_sequences_90_augmented.fasta
# 1.14.13.28_clustered_sequences_90_augmented.fasta
# 1.14.13.29_clustered_sequences_90_augmented.fasta
# 1.14.13.2_clustered_sequences_90_augmented.fasta
# 1.14.13.30_clustered_sequences_90_augmented.fasta
# 1.14.13.31_clustered_sequences_90_augmented.fasta
# 1.14.13.33_clustered_sequences_90_augmented.fasta
# 1.14.13.34_clustered_sequences_90_augmented.fasta
# 1.14.13.36_clustered_sequences_90_augmented.fasta
# 1.14.13.37_clustered_sequences_90_augmented.fasta
# 1.14.13.38_clustered_sequences_90_augmented.fasta
# 1.14.13.39_clustered_sequences_90_augmented.fasta
# 1.14.13.3_clustered_sequences_90_augmented.fasta
# 1.14.13.40_clustered_sequences_90_augmented.fasta
# 1.14.13.41_clustered_sequences_90_augmented.fasta
# ...
# 5.5.1.2_clustered_sequences_90_augmented.fasta
# 5.5.1.30_clustered_sequences_90_augmented.fasta
# 5.5.1.32_clustered_sequences_90_augmented.fasta
# 5.5.1.33_clustered_sequences_90_augmented.fasta
# 5.5.1.3_clustered_sequences_90_augmented.fasta
# 5.5.1.4_clustered_sequences_90_augmented.fasta
# 5.5.1.5_clustered_sequences_90_augmented.fasta
# 5.5.1.6_clustered_sequences_90_augmented.fasta
# 5.5.1.7_clustered_sequences_90_augmented.fasta
# 5.5.1.8_clustered_sequences_90_augmented.fasta
# 5.5.1.9_clustered_sequences_90_augmented.fasta
# 5.5.1.B6_clustered_sequences_90_augmented.fasta
# 5.5.1.B7_clustered_sequences_90_augmented.fasta
# 5.6.1.1_clustered_sequences_90_augmented.fasta
# 5.6.1.2_clustered_sequences_90_augmented.fasta
# 5.6.1.3_clustered_sequences_90_augmented.fasta
# 5.6.1.4_clustered_sequences_90_augmented.fasta
# 5.6.1.5_clustered_sequences_90_augmented.fasta
# 5.6.1.6_clustered_sequences_90_augmented.fasta
# 5.6.1.7_clustered_sequences_90_augmented.fasta
# 5.6.1.8_clustered_sequences_90_augmented.fasta
# 5.6.2.1_clustered_sequences_90_augmented.fasta
# 5.6.2.2_clustered_sequences_90_augmented.fasta
# 5.99.1.2_clustered_sequences_90_augmented.fasta
# 5.99.1.3_clustered_sequences_90_augmented.fasta
# 5.99.1.4_clustered_sequences_90_augmented.fasta
# 6.1.1.10_clustered_sequences_90_augmented.fasta
# 6.1.1.11_clustered_sequences_90_augmented.fasta
# 6.1.1.12_clustered_sequences_90_augmented.fasta
# 6.1.1.13_clustered_sequences_90_augmented.fasta
# 6.1.1.14_clustered_sequences_90_augmented.fasta
# 6.1.1.15_clustered_sequences_90_augmented.fasta
# 6.1.1.16_clustered_sequences_90_augmented.fasta
# 6.1.1.17_clustered_sequences_90_augmented.fasta
# 6.1.1.18_clustered_sequences_90_augmented.fasta
# 6.1.1.19_clustered_sequences_90_augmented.fasta
# 6.1.1.1_clustered_sequences_90_augmented.fasta
# 6.1.1.20_clustered_sequences_90_augmented.fasta
# 6.1.1.21_clustered_sequences_90_augmented.fasta
# 6.1.1.22_clustered_sequences_90_augmented.fasta
# 6.1.1.23_clustered_sequences_90_augmented.fasta
# 6.1.1.24_clustered_sequences_90_augmented.fasta
# 6.1.1.25_clustered_sequences_90_augmented.fasta
# 6.1.1.26_clustered_sequences_90_augmented.fasta
# 6.1.1.27_clustered_sequences_90_augmented.fasta
# 6.1.1.2_clustered_sequences_90_augmented.fasta
# 6.1.1.3_clustered_sequences_90_augmented.fasta
# 6.1.1.4_clustered_sequences_90_augmented.fasta
# 6.1.1.5_clustered_sequences_90_augmented.fasta
# 6.1.1.6_clustered_sequences_90_augmented.fasta
# 6.1.1.7_clustered_sequences_90_augmented.fasta
# 6.1.1.8_clustered_sequences_90_augmented.fasta
# 6.1.1.9_clustered_sequences_90_augmented.fasta
# 6.1.1.B3_clustered_sequences_90_augmented.fasta
# 6.1.2.1_clustered_sequences_90_augmented.fasta
# 6.1.2.2_clustered_sequences_90_augmented.fasta
# 6.1.3.1_clustered_sequences_90_augmented.fasta
# 6.2.1.11_clustered_sequences_90_augmented.fasta
# 6.2.1.12_clustered_sequences_90_augmented.fasta
# 6.2.1.13_clustered_sequences_90_augmented.fasta
# 6.2.1.14_clustered_sequences_90_augmented.fasta
# 6.2.1.15_clustered_sequences_90_augmented.fasta
# 6.2.1.16_clustered_sequences_90_augmented.fasta
# 6.2.1.17_clustered_sequences_90_augmented.fasta
#  97%|█████████▋| 36090/37060 [00:14<00:00, 1170.05it/s]
# 6.2.1.18_clustered_sequences_90_augmented.fasta
# 6.2.1.19_clustered_sequences_90_augmented.fasta
# 6.2.1.1_clustered_sequences_90_augmented.fasta
# 6.2.1.20_clustered_sequences_90_augmented.fasta
# 6.2.1.21_clustered_sequences_90_augmented.fasta
# 6.2.1.22_clustered_sequences_90_augmented.fasta
# 6.2.1.24_clustered_sequences_90_augmented.fasta
# 6.2.1.25_clustered_sequences_90_augmented.fasta
# 6.2.1.26_clustered_sequences_90_augmented.fasta
# 6.2.1.27_clustered_sequences_90_augmented.fasta
# 6.2.1.28_clustered_sequences_90_augmented.fasta
# 6.2.1.29_clustered_sequences_90_augmented.fasta
# 6.2.1.2_clustered_sequences_90_augmented.fasta
# 6.2.1.30_clustered_sequences_90_augmented.fasta
# 6.2.1.31_clustered_sequences_90_augmented.fasta
# 6.2.1.32_clustered_sequences_90_augmented.fasta
# 6.2.1.33_clustered_sequences_90_augmented.fasta
# 6.2.1.34_clustered_sequences_90_augmented.fasta
# 6.2.1.35_clustered_sequences_90_augmented.fasta
# 6.2.1.36_clustered_sequences_90_augmented.fasta
# 6.2.1.37_clustered_sequences_90_augmented.fasta
# 6.2.1.39_clustered_sequences_90_augmented.fasta
# 6.2.1.3_clustered_sequences_90_augmented.fasta
# 6.2.1.40_clustered_sequences_90_augmented.fasta
# 6.2.1.41_clustered_sequences_90_augmented.fasta
# 6.2.1.42_clustered_sequences_90_augmented.fasta
# 6.2.1.43_clustered_sequences_90_augmented.fasta
# 6.2.1.44_clustered_sequences_90_augmented.fasta
# 6.2.1.45_clustered_sequences_90_augmented.fasta
# 6.2.1.46_clustered_sequences_90_augmented.fasta
# 6.2.1.47_clustered_sequences_90_augmented.fasta
# 6.2.1.48_clustered_sequences_90_augmented.fasta
# 6.2.1.49_clustered_sequences_90_augmented.fasta
# 6.2.1.4_clustered_sequences_90_augmented.fasta
# 6.2.1.50_clustered_sequences_90_augmented.fasta
# 6.2.1.51_clustered_sequences_90_augmented.fasta
# 6.2.1.52_clustered_sequences_90_augmented.fasta
# 6.2.1.53_clustered_sequences_90_augmented.fasta
# 6.2.1.54_clustered_sequences_90_augmented.fasta
# 6.2.1.55_clustered_sequences_90_augmented.fasta
# 6.2.1.5_clustered_sequences_90_augmented.fasta
# 6.2.1.6_clustered_sequences_90_augmented.fasta
# 6.2.1.7_clustered_sequences_90_augmented.fasta
# 6.2.1.8_clustered_sequences_90_augmented.fasta
# 6.2.1.9_clustered_sequences_90_augmented.fasta
# 6.2.1.B10_clustered_sequences_90_augmented.fasta
# 6.2.1.B11_clustered_sequences_90_augmented.fasta
# 6.2.1.B13_clustered_sequences_90_augmented.fasta
# 6.2.1.B1_clustered_sequences_90_augmented.fasta
# 6.2.1.B3_clustered_sequences_90_augmented.fasta
# 6.2.1.B4_clustered_sequences_90_augmented.fasta
# 6.2.1.B5_clustered_sequences_90_augmented.fasta
# 6.3.1.10_clustered_sequences_90_augmented.fasta
# 6.3.1.11_clustered_sequences_90_augmented.fasta
# 6.3.1.12_clustered_sequences_90_augmented.fasta
# 6.3.1.13_clustered_sequences_90_augmented.fasta
# 6.3.1.14_clustered_sequences_90_augmented.fasta
# 6.3.1.15_clustered_sequences_90_augmented.fasta
# 6.3.1.16_clustered_sequences_90_augmented.fasta
# 6.3.1.17_clustered_sequences_90_augmented.fasta
# 6.3.1.18_clustered_sequences_90_augmented.fasta
# 6.3.1.19_clustered_sequences_90_augmented.fasta
# 6.3.1.1_clustered_sequences_90_augmented.fasta
# 6.3.1.20_clustered_sequences_90_augmented.fasta
# 6.3.1.2_clustered_sequences_90_augmented.fasta
# 6.3.1.3_clustered_sequences_90_augmented.fasta
# 6.3.1.4_clustered_sequences_90_augmented.fasta
# 6.3.1.5_clustered_sequences_90_augmented.fasta
# 6.3.1.6_clustered_sequences_90_augmented.fasta
# 6.3.1.7_clustered_sequences_90_augmented.fasta
# 6.3.1.8_clustered_sequences_90_augmented.fasta
# 6.3.1.9_clustered_sequences_90_augmented.fasta
# 6.3.2.10_clustered_sequences_90_augmented.fasta
# 6.3.2.11_clustered_sequences_90_augmented.fasta
# 6.3.2.12_clustered_sequences_90_augmented.fasta
# 6.3.2.13_clustered_sequences_90_augmented.fasta
# 6.3.2.14_clustered_sequences_90_augmented.fasta
# 6.3.2.15_clustered_sequences_90_augmented.fasta
# 6.3.2.17_clustered_sequences_90_augmented.fasta
# 6.3.2.18_clustered_sequences_90_augmented.fasta
# 6.3.2.19_clustered_sequences_90_augmented.fasta
# 6.3.2.1_clustered_sequences_90_augmented.fasta
#  98%|█████████▊| 36319/37060 [00:14<00:00, 1241.66it/s]
# 6.3.2.20_clustered_sequences_90_augmented.fasta
# 6.3.2.21_clustered_sequences_90_augmented.fasta
# 6.3.2.22_clustered_sequences_90_augmented.fasta
# 6.3.2.23_clustered_sequences_90_augmented.fasta
# 6.3.2.25_clustered_sequences_90_augmented.fasta
# 6.3.2.26_clustered_sequences_90_augmented.fasta
# 6.3.2.27_clustered_sequences_90_augmented.fasta
# 6.3.2.28_clustered_sequences_90_augmented.fasta
# 6.3.2.29_clustered_sequences_90_augmented.fasta
# 6.3.2.2_clustered_sequences_90_augmented.fasta
# 6.3.2.30_clustered_sequences_90_augmented.fasta
# 6.3.2.31_clustered_sequences_90_augmented.fasta
# 6.3.2.32_clustered_sequences_90_augmented.fasta
# 6.3.2.33_clustered_sequences_90_augmented.fasta
# 6.3.2.34_clustered_sequences_90_augmented.fasta
# 6.3.2.35_clustered_sequences_90_augmented.fasta
# 6.3.2.36_clustered_sequences_90_augmented.fasta
# 6.3.2.37_clustered_sequences_90_augmented.fasta
# 6.3.2.38_clustered_sequences_90_augmented.fasta
# 6.3.2.39_clustered_sequences_90_augmented.fasta
# 6.3.2.3_clustered_sequences_90_augmented.fasta
# 6.3.2.41_clustered_sequences_90_augmented.fasta
# 6.3.2.42_clustered_sequences_90_augmented.fasta
# 6.3.2.43_clustered_sequences_90_augmented.fasta
# 6.3.2.44_clustered_sequences_90_augmented.fasta
# 6.3.2.45_clustered_sequences_90_augmented.fasta
# 6.3.2.46_clustered_sequences_90_augmented.fasta
# 6.3.2.47_clustered_sequences_90_augmented.fasta
# 6.3.2.48_clustered_sequences_90_augmented.fasta
# 6.3.2.49_clustered_sequences_90_augmented.fasta
# 6.3.2.4_clustered_sequences_90_augmented.fasta
# 6.3.2.51_clustered_sequences_90_augmented.fasta
# 6.3.2.52_clustered_sequences_90_augmented.fasta
# 6.3.2.53_clustered_sequences_90_augmented.fasta
# 6.3.2.5_clustered_sequences_90_augmented.fasta
# 6.3.2.6_clustered_sequences_90_augmented.fasta
# 6.3.2.7_clustered_sequences_90_augmented.fasta
# 6.3.2.8_clustered_sequences_90_augmented.fasta
# 6.3.2.9_clustered_sequences_90_augmented.fasta
# 6.3.2.B10_clustered_sequences_90_augmented.fasta
# 6.3.2.B11_clustered_sequences_90_augmented.fasta
# 6.3.2.B12_clustered_sequences_90_augmented.fasta
# 6.3.2.B15_clustered_sequences_90_augmented.fasta
# 6.3.2.B16_clustered_sequences_90_augmented.fasta
# 6.3.2.B19_clustered_sequences_90_augmented.fasta
# 6.3.2.B1_clustered_sequences_90_augmented.fasta
# 6.3.2.B23_clustered_sequences_90_augmented.fasta
# 6.3.2.B2_clustered_sequences_90_augmented.fasta
# 6.3.2.B3_clustered_sequences_90_augmented.fasta
# 6.3.2.B4_clustered_sequences_90_augmented.fasta
# 6.3.3.1_clustered_sequences_90_augmented.fasta
# 6.3.3.2_clustered_sequences_90_augmented.fasta
# 6.3.3.3_clustered_sequences_90_augmented.fasta
# 6.3.3.4_clustered_sequences_90_augmented.fasta
#  99%|█████████▊| 36523/37060 [00:14<00:00, 1056.12it/s]
# 6.3.3.5_clustered_sequences_90_augmented.fasta
# 6.3.3.6_clustered_sequences_90_augmented.fasta
# 6.3.3.7_clustered_sequences_90_augmented.fasta
# 6.3.4.10_clustered_sequences_90_augmented.fasta
# 6.3.4.11_clustered_sequences_90_augmented.fasta
# 6.3.4.12_clustered_sequences_90_augmented.fasta
# 6.3.4.13_clustered_sequences_90_augmented.fasta
# 6.3.4.14_clustered_sequences_90_augmented.fasta
# 6.3.4.15_clustered_sequences_90_augmented.fasta
# 6.3.4.16_clustered_sequences_90_augmented.fasta
# 6.3.4.18_clustered_sequences_90_augmented.fasta
# 6.3.4.19_clustered_sequences_90_augmented.fasta
# 6.3.4.1_clustered_sequences_90_augmented.fasta
# 6.3.4.20_clustered_sequences_90_augmented.fasta
# 6.3.4.21_clustered_sequences_90_augmented.fasta
# 6.3.4.22_clustered_sequences_90_augmented.fasta
# 6.3.4.23_clustered_sequences_90_augmented.fasta
# 6.3.4.24_clustered_sequences_90_augmented.fasta
# 6.3.4.2_clustered_sequences_90_augmented.fasta
# 6.3.4.3_clustered_sequences_90_augmented.fasta
# 6.3.4.4_clustered_sequences_90_augmented.fasta
# 6.3.4.5_clustered_sequences_90_augmented.fasta
# 6.3.4.6_clustered_sequences_90_augmented.fasta
# 6.3.4.7_clustered_sequences_90_augmented.fasta
# 6.3.4.8_clustered_sequences_90_augmented.fasta
# 6.3.4.9_clustered_sequences_90_augmented.fasta
# 6.3.5.10_clustered_sequences_90_augmented.fasta
# 6.3.5.11_clustered_sequences_90_augmented.fasta
# 6.3.5.12_clustered_sequences_90_augmented.fasta
# 6.3.5.1_clustered_sequences_90_augmented.fasta
# 6.3.5.2_clustered_sequences_90_augmented.fasta
# 6.3.5.3_clustered_sequences_90_augmented.fasta
#  99%|█████████▉| 36689/37060 [00:15<00:00, 899.68it/s]
# 6.3.5.4_clustered_sequences_90_augmented.fasta
# 6.3.5.5_clustered_sequences_90_augmented.fasta
# 6.3.5.6_clustered_sequences_90_augmented.fasta
# 6.3.5.7_clustered_sequences_90_augmented.fasta
# 6.3.5.8_clustered_sequences_90_augmented.fasta
# 6.3.5.9_clustered_sequences_90_augmented.fasta
# 6.4.1.1_clustered_sequences_90_augmented.fasta
# 6.4.1.2_clustered_sequences_90_augmented.fasta
# 6.4.1.3_clustered_sequences_90_augmented.fasta
# 6.4.1.4_clustered_sequences_90_augmented.fasta
# 6.4.1.5_clustered_sequences_90_augmented.fasta
# 6.4.1.6_clustered_sequences_90_augmented.fasta
# 6.4.1.7_clustered_sequences_90_augmented.fasta
# 6.4.1.8_clustered_sequences_90_augmented.fasta
# 6.4.1.9_clustered_sequences_90_augmented.fasta
# 6.5.1.1_clustered_sequences_90_augmented.fasta
# 6.5.1.2_clustered_sequences_90_augmented.fasta
# 6.5.1.3_clustered_sequences_90_augmented.fasta
# 6.5.1.4_clustered_sequences_90_augmented.fasta
# 6.5.1.5_clustered_sequences_90_augmented.fasta
# 6.5.1.6_clustered_sequences_90_augmented.fasta
# 6.5.1.7_clustered_sequences_90_augmented.fasta
# 6.5.1.8_clustered_sequences_90_augmented.fasta
# 6.5.1.B1_clustered_sequences_90_augmented.fasta
# 6.5.1.B3_clustered_sequences_90_augmented.fasta
# 6.6.1.1_clustered_sequences_90_augmented.fasta
# 6.6.1.2_clustered_sequences_90_augmented.fasta
# 7.1.1.1_clustered_sequences_90_augmented.fasta
# 7.1.1.2_clustered_sequences_90_augmented.fasta
# 100%|█████████▉| 37010/37060 [00:15<00:00, 620.97it/s]
# 7.1.1.3_clustered_sequences_90_augmented.fasta
# 7.1.1.4_clustered_sequences_90_augmented.fasta
# 7.1.1.5_clustered_sequences_90_augmented.fasta
# 7.1.1.6_clustered_sequences_90_augmented.fasta
# 7.1.1.7_clustered_sequences_90_augmented.fasta
# 7.1.1.8_clustered_sequences_90_augmented.fasta
# 7.1.2.1_clustered_sequences_90_augmented.fasta
# 7.1.2.2_clustered_sequences_90_augmented.fasta
# 7.1.3.1_clustered_sequences_90_augmented.fasta
# 7.2.1.1_clustered_sequences_90_augmented.fasta
# 7.2.1.2_clustered_sequences_90_augmented.fasta
# 7.2.1.3_clustered_sequences_90_augmented.fasta
# 7.2.2.10_clustered_sequences_90_augmented.fasta
# 7.2.2.11_clustered_sequences_90_augmented.fasta
# 7.2.2.12_clustered_sequences_90_augmented.fasta
# 7.2.2.13_clustered_sequences_90_augmented.fasta
# 7.2.2.14_clustered_sequences_90_augmented.fasta
# 7.2.2.15_clustered_sequences_90_augmented.fasta
# 7.2.2.16_clustered_sequences_90_augmented.fasta
# 7.2.2.17_clustered_sequences_90_augmented.fasta
# 7.2.2.18_clustered_sequences_90_augmented.fasta
# 7.2.2.19_clustered_sequences_90_augmented.fasta
# 7.2.2.1_clustered_sequences_90_augmented.fasta
# 7.2.2.2_clustered_sequences_90_augmented.fasta
# 7.2.2.3_clustered_sequences_90_augmented.fasta
# 7.2.2.4_clustered_sequences_90_augmented.fasta
# 7.2.2.5_clustered_sequences_90_augmented.fasta
# 7.2.2.6_clustered_sequences_90_augmented.fasta
# 7.2.2.7_clustered_sequences_90_augmented.fasta
# 7.2.2.8_clustered_sequences_90_augmented.fasta
# 7.2.2.9_clustered_sequences_90_augmented.fasta
# 7.2.4.1_clustered_sequences_90_augmented.fasta
# 7.2.4.2_clustered_sequences_90_augmented.fasta
# 7.2.4.3_clustered_sequences_90_augmented.fasta
# 7.2.4.4_clustered_sequences_90_augmented.fasta
# 7.3.2.1_clustered_sequences_90_augmented.fasta
# 7.3.2.2_clustered_sequences_90_augmented.fasta
# 7.3.2.3_clustered_sequences_90_augmented.fasta
# 7.3.2.4_clustered_sequences_90_augmented.fasta
# 7.3.2.5_clustered_sequences_90_augmented.fasta
# 7.3.2.6_clustered_sequences_90_augmented.fasta
# 7.4.2.1_clustered_sequences_90_augmented.fasta
# 7.4.2.2_clustered_sequences_90_augmented.fasta
# 7.4.2.3_clustered_sequences_90_augmented.fasta
# 7.4.2.4_clustered_sequences_90_augmented.fasta
# 7.4.2.5_clustered_sequences_90_augmented.fasta
# 7.4.2.6_clustered_sequences_90_augmented.fasta
# 7.4.2.7_clustered_sequences_90_augmented.fasta
# 7.4.2.8_clustered_sequences_90_augmented.fasta
# 7.4.2.9_clustered_sequences_90_augmented.fasta
# 7.5.2.1_clustered_sequences_90_augmented.fasta
# 7.5.2.3_clustered_sequences_90_augmented.fasta
# 7.5.2.4_clustered_sequences_90_augmented.fasta
# 7.5.2.5_clustered_sequences_90_augmented.fasta
# 7.5.2.6_clustered_sequences_90_augmented.fasta
# 7.5.2.B6_clustered_sequences_90_augmented.fasta
# 7.5.2.B7_clustered_sequences_90_augmented.fasta
# 7.6.2.10_clustered_sequences_90_augmented.fasta
# 7.6.2.11_clustered_sequences_90_augmented.fasta
# 100%|██████████| 37060/37060 [00:15<00:00, 2346.55it/s]
# 7.6.2.12_clustered_sequences_90_augmented.fasta
# 7.6.2.1_clustered_sequences_90_augmented.fasta
# 7.6.2.2_clustered_sequences_90_augmented.fasta
# 7.6.2.4_clustered_sequences_90_augmented.fasta
# 7.6.2.5_clustered_sequences_90_augmented.fasta
# 7.6.2.6_clustered_sequences_90_augmented.fasta
# 7.6.2.7_clustered_sequences_90_augmented.fasta
# 7.6.2.8_clustered_sequences_90_augmented.fasta
# 7.6.2.9_clustered_sequences_90_augmented.fasta

# %% [markdown]
# ### Go through Pfam file to find the domains

# %%
def get_doms(data, filepath):
    '''
    Try to find domains for the identifiers.
    Uses pre-computed Pfam file.
    '''
    all_uid = set(data.keys())
    start_found = False
    counter = 0
    with open(filepath, 'r', encoding="latin-1") as f: #latin-1 to deal with a small number of byte codes in the file
        for line in f:
            # find beginning of a pfam domain record
            if line.startswith('#=GF AC'):
                if start_found is False: # if I find two starts in a row something went wrong
                    pfam = line.split()[2].rstrip()
                    start_found = True
                else:
                    raise ValueError

            elif line.startswith('#'): # skip other annotation fields
                continue

            elif line.startswith('//'): # if I find the end before the start something went wrong
                if start_found is True:
                    start_found = False
                else:
                    raise ValueError

            else:
                uid = line.split('.')[0]
                if uid in all_uid:
                    data[uid].append(pfam)
                    counter += 1

    print('found {} of {}'.format(counter, len(all_uid)))
    return data



def write_file(data, filepath):
    '''
    Write data to disk.
    '''
    outlines = []
    for uid in sorted(data.keys()):
        outlines.append('{}\t{}'.format(uid, ','.join(data[uid])))

    with open(filepath, 'w') as f:
        f.write('\n'.join(outlines))


        
def load_file(filepath):
    '''
    Get data from disk.
    '''
    data =  {}
    with open(filepath, 'r') as f:
        for line in f:
            parts = line.strip().split('\t')
            uid = parts[0]

            if len(parts) == 1:
                data[uid] = []
            else:
                domains = parts[1]
                data[uid] = domains
    return data
        
        
# parse the fasta files and get the uniprot identifiers
outfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'dom_temp_data.tsv')
if not exists(outfile):
    data = get_identifiers()

    # parse the pfam file and get domains for the identifiers
    data = get_doms(data, join('brenda_domains', 'Pfam-A.full.uniprot'))

    # save data
    write_file(data, outfile)
    
    
# how many do not have a domain?
data = load_file(outfile)
print('{} sequences missing domain prediction'.format(list(data.values()).count([])))
# Out:
# 172863 sequences missing domain prediction

# %% [markdown]
# ### Query UniProt for missing domains, but only for the characterized sequences

# %%
def get_characterized():
    # get a dictionary of characterized identifiers from BRENDA
    characterized = {}
    with open(join(INTERMEDIATE, 'BRENDA_for_paper', 'parsed_info', 'ec_data_uid_orgs.tsv'), 'r') as f:
        f.readline()

        for line in f:
            ec, org, uid = line.rstrip().split('\t')

            if characterized.get(ec) is None:
                characterized[ec] = set([])
            characterized[ec].add(uid)
            
    # get all characterized identifiers from SwissProt
    with open(join(INTERMEDIATE, 'swissprot_2020_02', 'SwissProt-2020_02-protein-evidence.tsv'), 'r') as f:
        f.readline()
        
        for line in f:
            uid, ec, org, orgid = line.strip().split('\t')
            
            if characterized.get(ec) is None:
                characterized[ec] = set([])
            characterized[ec].add(uid)
            
    return characterized


def dlfile(folder, filename, url):
    '''
    Download a web page if the corresponding file does not exist.
    '''

    # Open the url
    try:
        out_path = join(folder, filename)
        if exists(out_path):
            print('already on disk ' + url)
            return True
            
        elif not exists(out_path):
            f = urlopen(url)
            print("downloading " + url)

            # Open local file for writing
            with open(out_path, "wb") as local_file:
                local_file.write(f.read())
            time.sleep(0.5)
            return True

    #handle errors
    except HTTPError as e:
        print("HTTP Error:", e.code, url)
        return False
    
    except URLError as e:
        print("URL Error:", e.reason, url)
        return False
        

def get_pfam_from_file(filepath):
    '''
    Parse out pfam data from a file
    '''
    # open the uniprot and uniparc pages and append them
    with open(filepath, 'r') as f:
        document = f.read()

        
    # search through the combined document for identifiers
    m = re.findall('(PF[0-9]{5}|CL[0-9]{4})', document)

    # loop through the search result and keep unique identifiers
    pfam_ids = set([])
    for pid in m:
        if pid == '':
            continue
                
        pfam_ids.add(pid)
        
    return pfam_ids
        
    
    
def get_pfam_for_uids(uids, filepath):
    '''
    Query the UniProt database to get protein domains for 
    a list of protein identifiers.
    '''

    data = {'uid':[], 'pfam':[]}

    for uid in tqdm(uids):

        # download uniprot file
        uniprot_url = 'https://www.uniprot.org/uniprot/'
        result = dlfile(folder=filepath, filename='%s_uniprot.html' % uid, url=uniprot_url+uid)
        if result is False:
            continue

        # query uniprot file
        pfam_ids = get_pfam_from_file(join(filepath, '%s_uniprot.html' % uid))


        # download uniparc overview file
        uniparc_url = 'https://www.uniprot.org/uniparc/?query=%s' % uid
        overview_filename = join(filepath, '%s_uniparc_overview.html' % uid)
        result = dlfile(folder=filepath, filename='%s_uniparc_overview.html' % uid, url=uniparc_url)
        if result is False:
            continue

        # find the reference for the alternate identifier and download that file
        with open(overview_filename, 'r') as f:
            document = f.read()

            m = re.search('class="entryID"><a href="/uniparc/([a-zA-Z0-9]+)">', document)
            new_target_url = 'https://www.uniprot.org/uniparc/%s' % m.group(1)
            result = dlfile(folder=filepath, filename='%s_uniparc.html' % uid, url=new_target_url)
            if result is False:
                continue

        # query uniparc file
        pfam_ids2 = get_pfam_from_file(join(filepath, '%s_uniparc.html' % uid))


        data['uid'].append(uid)
        data['pfam'].append(','.join(sorted(list(pfam_ids.union(pfam_ids2)))))

    
    return pd.DataFrame(data)




# get characterized identfiers
characterized = get_characterized()
uids = set([])
for ec in characterized.keys():
    uids.update(characterized[ec])
len(uids)

# which identifiers are considered characterized but have not predicted domain?
missing = uids - set(data.keys())
print(len(missing))

# now download these
filepath = join(RAW_EXTERNAL, 'pfam')
get_pfam_for_uids(sorted(list(missing), reverse=True), filepath)
# Out:
#   0%|          | 0/337 [00:00<?, ?it/s]
# 337
# downloading https://www.uniprot.org/uniprot/W5QJZ5
# downloading https://www.uniprot.org/uniparc/?query=W5QJZ5
# downloading https://www.uniprot.org/uniparc/UPI0003EC8843
#   0%|          | 1/337 [00:07<43:41,  7.80s/it]
# downloading https://www.uniprot.org/uniprot/V5TF65
# downloading https://www.uniprot.org/uniparc/?query=V5TF65
# downloading https://www.uniprot.org/uniparc/UPI0002DC68A7
#   1%|          | 2/337 [00:15<42:45,  7.66s/it]
# downloading https://www.uniprot.org/uniprot/V5TDZ4
# downloading https://www.uniprot.org/uniparc/?query=V5TDZ4
# downloading https://www.uniprot.org/uniparc/UPI0003167E2A
#   1%|          | 3/337 [00:21<41:04,  7.38s/it]
# downloading https://www.uniprot.org/uniprot/V5TD11
# downloading https://www.uniprot.org/uniparc/?query=V5TD11
# downloading https://www.uniprot.org/uniparc/UPI0003D843B9
#   1%|          | 4/337 [00:29<40:35,  7.31s/it]
# downloading https://www.uniprot.org/uniprot/U5NE19
# downloading https://www.uniprot.org/uniparc/?query=U5NE19
# downloading https://www.uniprot.org/uniparc/UPI0003BA04D8
#   1%|▏         | 5/337 [00:35<39:21,  7.11s/it]
# downloading https://www.uniprot.org/uniprot/Q9ZI86
# downloading https://www.uniprot.org/uniparc/?query=Q9ZI86
# downloading https://www.uniprot.org/uniparc/UPI000012E7A0
#   2%|▏         | 6/337 [00:42<38:23,  6.96s/it]
# downloading https://www.uniprot.org/uniprot/Q9Y6E7
# downloading https://www.uniprot.org/uniparc/?query=Q9Y6E7
# downloading https://www.uniprot.org/uniparc/UPI0000071F11
#   2%|▏         | 7/337 [00:50<40:10,  7.31s/it]
# downloading https://www.uniprot.org/uniprot/Q9WYW0
# downloading https://www.uniprot.org/uniparc/?query=Q9WYW0
# downloading https://www.uniprot.org/uniparc/UPI00000D39F3
#   2%|▏         | 8/337 [00:57<39:52,  7.27s/it]
# downloading https://www.uniprot.org/uniprot/Q9W5E0
# downloading https://www.uniprot.org/uniparc/?query=Q9W5E0
# downloading https://www.uniprot.org/uniparc/UPI000007F6B5
#   3%|▎         | 9/337 [01:10<49:36,  9.08s/it]
# downloading https://www.uniprot.org/uniprot/Q9VK34
# downloading https://www.uniprot.org/uniparc/?query=Q9VK34
# downloading https://www.uniprot.org/uniparc/UPI000007CC5D
#   3%|▎         | 10/337 [01:18<46:25,  8.52s/it]
# downloading https://www.uniprot.org/uniprot/Q9VFK6
# downloading https://www.uniprot.org/uniparc/?query=Q9VFK6
# downloading https://www.uniprot.org/uniparc/UPI00001247DE
#   3%|▎         | 11/337 [01:25<44:37,  8.21s/it]
# downloading https://www.uniprot.org/uniprot/Q9VAQ1
# downloading https://www.uniprot.org/uniparc/?query=Q9VAQ1
# downloading https://www.uniprot.org/uniparc/UPI0000079982
#   4%|▎         | 12/337 [01:32<42:23,  7.83s/it]
# downloading https://www.uniprot.org/uniprot/Q9UW95
# downloading https://www.uniprot.org/uniparc/?query=Q9UW95
# downloading https://www.uniprot.org/uniparc/UPI000006B230
#   4%|▍         | 13/337 [01:39<40:31,  7.51s/it]
# downloading https://www.uniprot.org/uniprot/Q9UMN6
# downloading https://www.uniprot.org/uniparc/?query=Q9UMN6
# downloading https://www.uniprot.org/uniparc/UPI00001376B5
#   4%|▍         | 14/337 [01:48<42:41,  7.93s/it]
# downloading https://www.uniprot.org/uniprot/Q9UKV8
# downloading https://www.uniprot.org/uniparc/?query=Q9UKV8
# downloading https://www.uniprot.org/uniparc/UPI000012D07E
#   4%|▍         | 15/337 [01:56<43:47,  8.16s/it]
# downloading https://www.uniprot.org/uniprot/Q9UJ83
