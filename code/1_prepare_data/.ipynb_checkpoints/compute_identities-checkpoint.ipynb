# %% [markdown]
# This notebook is for calculating identities between all BRENDA sequences and their closest characterized one.<br/><br/>Copyright (C) 2019  Martin Engqvist Lab<br/>This program is free software: you can redistribute it and/or modify<br/>it under the terms of the GNU General Public License as published by<br/>the Free Software Foundation, either version 3 of the License, or<br/>(at your option) any later version.<br/>This program is distributed in the hope that it will be useful,<br/>but WITHOUT ANY WARRANTY; without even the implied warranty of<br/>MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the<br/>GNU General Public License for more details.<br/>You should have received a copy of the GNU General Public License<br/>along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %%
import os
from dotenv import load_dotenv, find_dotenv
from os.path import join, dirname, basename, exists, isdir

### Load environmental variables from the project root directory ###
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)

# now you can get the variables using their names

# Check whether a network drive has been specified
DATABASE = os.environ.get("NETWORK_URL")
if DATABASE == 'None':
    pass
else:
    pass
    #mount network drive here

# set up directory paths
CURRENT_DIR = os.getcwd()
PROJ = dirname(dotenv_path) # project root directory

DATA = join(PROJ, 'data') #data directory
RAW_EXTERNAL = join(DATA, 'raw_external') # external data raw directory
RAW_INTERNAL = join(DATA, 'raw_internal') # internal data raw directory
INTERMEDIATE = join(DATA, 'intermediate') # intermediate data directory
FINAL = join(DATA, 'final') # final data directory

RESULTS = join(PROJ, 'results') # output directory
FIGURES = join(RESULTS, 'figures') # figure output directory
PICTURES = join(RESULTS, 'pictures') # picture output directory


folder_name = 'brenda_2019_2'
if folder_name != '':
    #make folders if they don't exist
    if not exists(join(RAW_EXTERNAL, folder_name)):
        os.makedirs(join(RAW_EXTERNAL, folder_name))

    if not exists(join(INTERMEDIATE, folder_name)):
        os.makedirs(join(INTERMEDIATE, folder_name))

    if not exists(join(FINAL, folder_name)):
        os.makedirs(join(FINAL, folder_name))

print('Standard variables loaded, you are good to go!')
# Out:
# Standard variables loaded, you are good to go!

# %%
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.Align.Applications import MuscleCommandline
from Bio import AlignIO
from Bio.SeqRecord import SeqRecord
from Bio.Alphabet import IUPAC
import io

from subprocess import Popen, PIPE
import random
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import spearmanr
import multiprocessing


# https://doi.org/10.1186/s13059-017-1319-7
# https://github.com/aziele/alfpy
# http://www.combio.pl/alfree

from alfpy.utils import seqrecords
from alfpy import word_distance
from alfpy import word_pattern
from alfpy import word_vector
from alfpy.utils import distmatrix
from alfpy import ncd

# %% [markdown]
# ### Compute identity between characterized sequences and all sequences in clustered fasta

# %% [markdown]
# I want to use the alignment-free k-tuple measure to obtain the best matach between characterized and uncharacterized sequences, then do a pairwise alignment to get the correct identiy. However, I do not know the best settings for the k-tuple algorithm to mimic an alignment. Will have to explore this first.

# %% [markdown]
# #### Compute all vs all identity using alignment

# %%
def pairwise_align(id1, id2, seq1, seq2):
    '''
    Perform pairwise alignment.
    '''
    records = '>%s\n%s\n>%s\n%s' % (id1, seq1, id2, seq2) #prepare 'virtual' FASTA file
    records_handle = io.StringIO(records) #turn string into a handle
    tempdata = records_handle.getvalue()
    muscle_cline = MuscleCommandline()
    stdout, stderr = muscle_cline(stdin=tempdata)
    
    with io.StringIO(stdout) as fasta:
        aln = SeqIO.parse(fasta, "fasta")

        output = []
        for entry in aln:
            header = entry.description
            seq = entry.seq

            output.append(header)
            output.append(seq)
        
    return output




def pair_ident(Seq1, Seq2, single_gaps=True):
    '''
    Takes two aligned sequences and returns their percent identity.
    Assumes that Seq1 and Seq2 are sequence strings
    '''

    l=0.0 # counts alignment length, excluding identical gaps, but including single gaps
    n=0.0 # count number of single gaps
    i=0.0 # counts identity hits


    for j in range(len(Seq2)):
        if Seq1[j] == '-' and Seq2[j] == '-': #DON'T count identical gaps towards alignment length
            pass
        else:
            if Seq2[j] == Seq1[j]:
                i += 1 #count matches
            elif Seq2[j] == '-' or Seq1[j] == '-':
                n += 1 #count number of single gaps
            l += 1 #count total length with single gaps

    if single_gaps is True: #include single gaps
        percent = round(100*(i/l),1) #calculate identity

    elif single_gaps is False: #exclude single gaps
        if n >= l:
            percent = 0.0
        else:
            percent = round(100*(i/(l-n)),1) #calculate identity

    return percent



def get_random_selection(ec, num_seqs, seed=1):
    '''
    Randomnly select sequences from 1.1.3.15 on which to do all vs all identities
    '''
    random.seed(seed)

    # first get all sequences
    all_seqs = []
    all_ids = []
    filepath = join(INTERMEDIATE, 'BRENDA_for_paper', 'ec_identity_clustering')
    fasta_filepath = join(filepath, '%s_clustered_sequences_90_augmented.fasta' % ec)
    fasta = SeqIO.parse(fasta_filepath, "fasta")
    for record in fasta:
        header = record.description
        uid = header.split(';')[0].rstrip()
        seq = record.seq

        all_ids.append(uid)
        all_seqs.append(str(seq))


    # now select sequences at random
    sampling = random.choices(list(range(0, len(all_ids))), k=num_seqs)
    my_seqs = [all_seqs[i] for i in sampling]
    my_ids = [all_ids[i] for i in sampling]
    
    return my_ids, my_seqs




def compute_matrix():
    # compute identities using alignment 
    id_matrix = np.zeros((num_seqs, num_seqs))
    for i in range(0, len(my_ids)):
        for j in (range(0, len(my_ids))):
            id1 = my_ids[i]
            seq1 = my_seqs[i]

            id2 = my_ids[j]
            seq2 = my_seqs[j]

            output = pairwise_align(id1=id1, id2=id2, seq1=seq1, seq2=seq2)

            aln_seq1 = output[1]
            aln_seq2 = output[3]

            identity = pair_ident(Seq1=aln_seq1, Seq2=aln_seq2, single_gaps=True)

            id_matrix[i, j] = identity

    # convert to distance matrix
    dist_matrix = 1-(id_matrix/100)
    
    return dist_matrix


num_seqs = 40
my_ids, my_seqs = get_random_selection(ec='1.1.3.15', num_seqs=num_seqs)

outfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'alignment_distmatrix_for_ktup_settings_evaluation.tsv')
if not exists(outfile):
    dist_matrix = compute_matrix()
    np.savetxt(outfile, dist_matrix, delimiter='\t')
else:
    dist_matrix = np.loadtxt(outfile, delimiter='\t')

# %% [markdown]
# #### Compute distances using several k-tuple measures and plot

# %%
seq_records = seqrecords.SeqRecords(id_list=my_ids, seq_list=my_seqs)


settings = []
matrixes = []
for measure in ['angle_cos_diss',
                'angle_cos_evol',
                'braycurtis',
                'canberra',
                'chebyshev',
                'euclid_norm',
                'euclid_squared',
                'google',
                'jsd',
                'kld',
                'lcc',
                'manhattan',
                'minkowski']:
    for word_vec in ['counts']:
        for word_size in [2, 3, 4]:

            settings.append('vector type: %s, word size: %s, dist measure: %s' % (word_vec, word_size, measure))

            p = word_pattern.create(seq_records.seq_list, word_size=word_size)
            
            if word_vec == 'counts':
                counts = word_vector.Counts(seq_records.length_list, p)
                dist = word_distance.Distance(counts, measure)
                
            elif word_vec == 'freqs':
                freqs = word_vector.Freqs(seq_records.length_list, p)
                dist = word_distance.Distance(freqs, measure)
                
            else:
                raise ValueError
                
                
            matrix = distmatrix.create(seq_records.id_list, dist)
            matrixes.append(matrix)

# %% [markdown]
# #### Plot k-tuple vs alignment sores

# %%
ncols = 3
nrows = int(len(matrixes)/ncols)

fig = plt.figure(figsize=(10,44))

for i in range(0, len(matrixes)):
    x = list(matrixes[i].data[np.triu_indices(num_seqs, k=1)])
    y = list(dist_matrix[np.triu_indices(num_seqs, k=1)])

    plt.subplot(nrows, ncols, i+1)
    plt.scatter(x, y)
    plt.ylim(0, 1)
    
    # calculate spearman correlation
    coef, p = spearmanr(x, y)
    plt.text(x=max(x)-(max(x)-min(x))/3, y=0.2, s='rho=%.2f' % coef)
    plt.text(x=max(x)-(max(x)-min(x))/3, y=0.1, s='p=%.2f' % p)

    plt.xlabel('K-tuple based distance')
    plt.ylabel('Alignment-based distance')
    plt.title(settings[i].replace(',', '\n'))


plt.tight_layout()


plt.savefig(join(FIGURES, 'k-tuple_settings_plot.png'), dpi=300, 
        facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1, metadata=None)


plt.savefig(join(FIGURES, 'k-tuple_settings_plot.pdf'),
        facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1, metadata=None)

# %% [markdown]
# From this I conclude that both google with a word size of 3 is the best one to use, closely followed by baycurtis also with a wordsize of 3.

# %% [markdown]
# ### Use the best K-tuple method for identifying which sequence is the closest characterized one

# %% [markdown]
# I will use the k-tuple measure to find the most similar characterized sequences for each uncharacterized one. I will then align these to get an accurate measure of how similar they are.

# %%
def make_flatfile(data, header, outfile, has_uid):
    '''
    Generic function for saving the flatfiles
    '''
    out_data = [header]
    for ec in sorted(data.keys()):
        for org in sorted(data[ec].keys()):
            domain = data[ec][org]['domain']
            
            if domain is None:
                if has_uid is False:
                    out_data.append('%s\t%s' % (ec, org))

                elif has_uid is True:
                    for uid in data[ec][org]['uids']:
                            out_data.append('%s\t%s\t%s' % (ec, org, uid))
                            
            else:
                if has_uid is False:
                    out_data.append('%s\t%s\t%s' % (ec, org, domain))

                elif has_uid is True:
                    for uid in data[ec][org]['uids']:
                            out_data.append('%s\t%s\t%s\t%s' % (ec, org, uid, domain))
                        
    with open(outfile, 'w') as f:
        f.write('\n'.join(out_data))
        

        
def load_flatfile(infile, has_uid):
    '''
    Generic function for loading the flatfiles
    '''
    data = {}
    with open(infile, 'r') as f:
        f.readline()
        for line in f:
            
            if has_uid is True:
                if len(line.strip().split('\t')) == 4:
                    ec, org, uid, domain = line.strip().split('\t')
                else:
                    ec, org, uid = line.strip().split('\t')
                    domain = None
                
                if data.get(ec) is None:
                    data[ec] = {}

                if data[ec].get(org) is None:
                    data[ec][org] = {'uids':[], 'domain':None}
                
                data[ec][org]['uids'].append(uid.upper())
                data[ec][org]['domain'] = domain
                
                
            elif has_uid is False:
                if len(line.strip().split('\t')) == 3:
                    ec, org, domain = line.strip().split('\t')
                else:
                    ec, org = line.strip().split('\t')
                    domain = None
                
                if data.get(ec) is None:
                    data[ec] = {}

                if data[ec].get(org) is None:
                    data[ec][org] = {'uids':None, 'domain':None}

                data[ec][org]['domain'] = domain
                
            else:
                raise ValueError
            
            
    return data


def get_ec_uid_and_seq(ec):
    '''
    Return nested dictionary with EC number primary keys and uid values.
    In the second level each uid holds its protein sequence.
    Only return for uniprot identifiers from a specific ec.
    '''
    data = {}
    
    filepath = join(INTERMEDIATE, 'BRENDA_for_paper', 'ec_identity_clustering')
    fasta_filepath = join(filepath, '%s_clustered_sequences_90_augmented.fasta' % ec)
    
    # go through each entry in the fasta
    fasta = SeqIO.parse(fasta_filepath, "fasta")
    for record in fasta:
        header = record.description
        uid = header.split(';')[0].rstrip().upper()
        seq = record.seq

        data[uid] = seq

    return data


def calculate_ktup_identities(ec, data, tempfile):
    '''
    Loop through all the EC classes and compare characterized sequences with uncharacterized ones.
    '''

    # get all the sequences in clustered fasta
    seq_data = get_ec_uid_and_seq(ec) 

    # assemble a list of the characterized sequences
    char_ids = []
    char_seqs = []

    if ec_org_uid_data.get(ec) is None:
        pass
    else:
        for char_org in sorted(ec_org_uid_data[ec].keys()):
            for char_uid in ec_org_uid_data[ec][char_org]['uids']:
                char_ids.append(char_uid)
                char_seqs.append(str(seq_data[char_uid]))

    print('%s: %s characterized, %s sequences total' % (ec, len(char_ids), len(list(seq_data.keys()))))

#     print(char_ids)
#     print(char_seqs)

    # now go through the uncharacterized sequences one by one and get the closest characterized one
    counter = 0
    for organism in sorted(data.keys()):
        data[organism]['closest_match'] = []
        data[organism]['ktuple_dist'] = []

        for uid in data[organism]['uids']:
            uid = uid
            
            counter += 1
            if counter % 500 == 0:
                print(ec, counter)

            closest_match = 'None'
            best_score = 1.0

            # if none are characterized put 0 on all
            if len(char_ids) is None:
                data[organism]['closest_match'].append(closest_match)
                data[organism]['ktuple_dist'].append('%.3f' % best_score)
                continue


            # get sequence for this uid
            if seq_data.get(uid) is None:
                print(uid, ec)
            seq = seq_data[uid]

            # compare in turn with each of the characterized ones
            for i in range(0, len(char_ids)):
                tmp_ids = [char_ids[i]] + [uid]
                tmp_seqs = [char_seqs[i]] + [str(seq)]

                # make k-tupe calculation
                seq_records = seqrecords.SeqRecords(id_list=tmp_ids, seq_list=tmp_seqs)
                p = word_pattern.create(seq_records.seq_list, word_size=3)

                counts = word_vector.Counts(seq_records.length_list, p)
                dist = word_distance.Distance(counts, 'google')
                matrix = distmatrix.create(seq_records.id_list, dist)

                # get the last column (which contains data for the last added identifier)
                ktup_dist = matrix.data[0, 1]

                if ktup_dist < best_score:
                    best_score = ktup_dist
                    closest_match = char_ids[i]

            data[organism]['closest_match'].append(closest_match)
            data[organism]['ktuple_dist'].append('%.3f' % best_score)
            
            
    # now save the data to disk in case I have to re-run the computation
    write_temp_flatfile(data, tempfile)




def count_many(data):
    '''
    Takes a list of many filepaths (full os path to file) and uses paralell processing to count frequencies in these.
    Returns a list of tuples with (filepath, occurance_dictionary).
    WARNING: The order of the files in the result may not be the same as in the input.
    '''
    # split up det data on a per ec basis
    packages = []
    for ec in sorted(data.keys()):

        tempfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'ktup_temp_data', '%s.tsv' % ec)

        if not exists(tempfile):
            calculate_ktup_identities(ec, data[ec], tempfile)



def write_temp_flatfile(data, outfile):
    '''
    For saving data from each ec number, in case computation does not finish.
    '''
    out_data = ['organism\tuid\tdomain\tbest_match\tktuple_dist']
    for org in sorted(data.keys()):
        domain = data[org]['domain']

        for i in range(len(data[org]['uids'])):
            uid = data[org]['uids'][i]
            best_match = data[org]['closest_match'][i]
            ktup = data[org]['ktuple_dist'][i]
            out_data.append('%s\t%s\t%s\t%s\t%s' % (org, uid, domain, best_match, ktup))
                        
    with open(outfile, 'w') as f:
        f.write('\n'.join(out_data))



def load_temp_flatfile(infile):
    '''
    For loading data from each ec number, in case computation was interrupted in previous runs.
    '''
    print('Loading %s' % infile)
    data = {}
    with open(infile, 'r') as f:
        f.readline()
        for line in f:
            org, uid, domain, best_match, ktup = line.strip().split('\t')
            
            if data.get(org) is None:
                data[org] = {'closest_match':[], 'ktuple_dist':[], 'uids':[], 'domain':domain}
              
            data[org]['uids'].append(uid)
            data[org]['closest_match'].append(best_match)
            data[org]['ktuple_dist'].append(ktup)
    
    return data
        
        
        
        
def write_final_ktup_flatfile(data, outfile):
    '''
    '''
    out_data = ['ec\torganism\tuid\tdomain\tbest_match\tktuple_dist']
    for ec in sorted(data.keys()):
        for org in sorted(data[ec].keys()):
            domain = data[ec][org]['domain']

            for i in range(len(data[ec][org]['uids'])):
                uid = data[ec][org]['uids'][i]
                best_match = data[ec][org]['closest_match'][i]
                identity = data[ec][org]['ktuple_dist'][i]
                out_data.append('%s\t%s\t%s\t%s\t%s\t%s' % (ec, org, uid, domain, best_match, identity))
                        
    with open(outfile, 'w') as f:
        f.write('\n'.join(out_data))
        

infile_fasta = join(INTERMEDIATE, 'BRENDA_for_paper', 'parsed_info', 'fasta_data_ec_uid_orgs_domain_2.tsv')
fasta_data = load_flatfile(infile_fasta, has_uid=True)           

infile_html = join(INTERMEDIATE, 'BRENDA_for_paper', 'parsed_info', 'ec_data_uid_orgs_domain_2.tsv')
ec_org_uid_data = load_flatfile(infile_html, has_uid=True)


# calculate the k-tuple measures
count_many(fasta_data)

# load each of the individual files
outfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'parsed_info', 'fasta_data_ec_uid_orgs_domain_2_kdist.tsv')

if not exists(outfile):
    ktup_data = {}
    folder_path = join(INTERMEDIATE, 'BRENDA_for_paper', 'ktup_temp_data')
    for fi in sorted(os.listdir(folder_path)):
        ec = '.'.join(fi.split('.')[:-1])
        ktup_data[ec] = load_temp_flatfile(join(folder_path, fi))

    # make a single outfile
    write_final_ktup_flatfile(ktup_data, outfile)

print('done')
# Out:
# done

# %% [markdown]
# ### Go through each of the characterized-uncharacterized pairs (smallest distance) and compute true aligned identifies

# %%
def load_final_ktup_flatfile(infile):
    '''
    For loading data from each ec number, in case computation was interrupted in previous runs.
    '''
    data = {}
    with open(infile, 'r') as f:
        f.readline()
        for line in f:
            ec, org, uid, domain, best_match, identity = line.strip().split('\t')

            if data.get(ec) is None:
                data[ec] = {}
            
            if data[ec].get(org) is None:
                data[ec][org] = {'closest_match':[], 'ktuple_dist':[], 'uids':[], 'domain':domain}
              
            if uid != 'None':
                uid = uid.upper()

            if best_match != 'None':
                best_match = best_match.upper()
            
            data[ec][org]['uids'].append(uid)
            data[ec][org]['closest_match'].append(best_match)
            data[ec][org]['ktuple_dist'].append(identity)
    
    return data



def worker(package):
    '''
    '''
    index, org, id1, seq1, id2, seq2 = package

    # sometimes there is no closest match (i.e. no characterized sequence)
    if id2 == 'None':
        return (index, org, 0)
    
    id1 = '>%s'  %id1
    id2 = '>%s' % id2

    output = pairwise_align(id1=id1, id2=id2, seq1=seq1, seq2=seq2)

    aln_seq1 = output[1]
    aln_seq2 = output[3]

    identity = pair_ident(Seq1=aln_seq1, Seq2=aln_seq2, single_gaps=True)
    
    return (index, org, identity)




def align_all():
    '''
    '''
    
    data = load_final_ktup_flatfile(join(INTERMEDIATE, 'BRENDA_for_paper', 'parsed_info', 'fasta_data_ec_uid_orgs_domain_2_kdist.tsv'))
    
    num_cores = multiprocessing.cpu_count()
    
    for ec in sorted(data.keys()):
        
        tempfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'aln_temp_data', '%s.tsv' % ec)
        
        if exists(tempfile):
            continue
 
        print(ec)
        
        seq_data = get_ec_uid_and_seq(ec) 
        
        packages = []
        for org in sorted(data[ec].keys()):
           
            for i in range(len(data[ec][org]['uids'])):
                id1 = data[ec][org]['uids'][i]
                id2 = data[ec][org]['closest_match'][i]

                # sometimes there is no closest match (i.e. no characterized sequence), the worker will return an identity of 0
                if id2 == 'None':
                    seq1 = ''
                    seq2 = ''

                else:
                    seq1 = seq_data[id1]
                    seq2 = seq_data[id2]

                packages.append((i, org, id1, seq1, id2, seq2))
            
        with multiprocessing.Pool(processes=num_cores) as pool:
            results = pool.map(worker, packages)
            
        # build empty list for each org
        for res in results:
            index, org, ident = res
            
            if data[ec][org].get('aln_ident') is None:
                data[ec][org]['aln_ident'] = [None for s in data[ec][org]['uids']]

            # add in identity data
            data[ec][org]['aln_ident'][index] = ident
            
            
        # save to file
        write_aln_temp_flatfile(data[ec], tempfile)
        
        

def write_aln_temp_flatfile(data, outfile):
    '''
    For saving data from each ec number, in case computation does not finish.
    '''
    out_data = ['organism\tuid\tdomain\tbest_match\tktuple_dist\tidentity']
    for org in sorted(data.keys()):
        domain = data[org]['domain']

        for i in range(len(data[org]['uids'])):
            uid = data[org]['uids'][i]
            best_match = data[org]['closest_match'][i]
            ktup = data[org]['ktuple_dist'][i]
            identity = data[org]['aln_ident'][i]
            out_data.append('%s\t%s\t%s\t%s\t%s\t%s' % (org, uid, domain, best_match, ktup, identity))
                        
    with open(outfile, 'w') as f:
        f.write('\n'.join(out_data))



def load_aln_temp_flatfile(infile):
    '''
    For loading data from each ec number, in case computation was interrupted in previous runs.
    '''
    print('Loading %s' % infile)
    data = {}
    with open(infile, 'r') as f:
        f.readline()
        for line in f:
            org, uid, domain, best_match, ktup, identity = line.strip().split('\t')
            
            if data.get(org) is None:
                data[org] = {'closest_match':[], 'ktuple_dist':[], 'aln_ident':[],
                             'uids':[], 'domain':domain}
              
            data[org]['uids'].append(uid)
            data[org]['closest_match'].append(best_match)
            data[org]['ktuple_dist'].append(ktup)
            data[org]['aln_ident'].append(identity)
    
    return data
    


def write_final_aln_flatfile(data, outfile):
    '''
    '''
    out_data = ['ec\torganism\tuid\tdomain\tbest_match\tktuple_dist\tidentity']
    for ec in sorted(data.keys()):
        for org in sorted(data[ec].keys()):
            domain = data[ec][org]['domain']

            for i in range(len(data[ec][org]['uids'])):
                uid = data[ec][org]['uids'][i]
                best_match = data[ec][org]['closest_match'][i]
                ktup = data[ec][org]['ktuple_dist'][i]
                identity = data[ec][org]['aln_ident'][i]
                out_data.append('%s\t%s\t%s\t%s\t%s\t%s\t%s' % (ec, org, uid, domain, best_match, ktup, identity))
                        
    with open(outfile, 'w') as f:
        f.write('\n'.join(out_data))
    
    
    
align_all()


# load each of the individual files
outfile = join(INTERMEDIATE, 'BRENDA_for_paper', 'parsed_info', 'fasta_data_ec_uid_orgs_domain_2_kdist_aln.tsv')

if not exists(outfile):
    aln_data = {}
    folder_path = join(INTERMEDIATE, 'BRENDA_for_paper', 'aln_temp_data')
    for fi in sorted(os.listdir(folder_path)):
        ec = '.'.join(fi.split('.')[:-1])
        aln_data[ec] = load_aln_temp_flatfile(join(folder_path, fi))

    # make a single outfile
    write_final_aln_flatfile(aln_data, outfile)


print('done')
# Out:
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.100.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.101.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.102.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.103.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.105.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.107.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.108.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.110.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.112.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.113.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.114.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.116.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.117.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.118.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.119.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.120.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.121.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.122.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.123.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.124.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.125.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.126.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.127.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.13.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.130.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.131.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.132.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.133.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.135.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.136.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.137.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.138.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.14.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.140.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.141.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.142.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.144.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.145.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.146.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.148.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.149.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.15.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.152.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.153.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.154.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.156.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.157.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.159.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.16.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.162.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.163.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.166.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.168.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.169.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.17.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.170.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.173.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.175.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.176.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.178.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.179.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.18.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.181.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.183.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.184.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.187.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.188.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.189.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.19.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.190.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.191.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.192.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.193.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.194.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.195.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.197.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.198.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.20.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.200.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.201.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.202.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.203.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.205.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.206.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.207.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.208.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.209.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.21.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.210.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.211.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.213.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.214.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.215.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.216.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.218.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.219.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.22.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.220.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.223.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.224.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.225.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.23.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.232.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.233.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.234.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.235.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.236.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.237.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.239.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.24.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.243.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.244.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.245.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.247.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.248.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.25.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.250.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.251.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.252.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.255.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.256.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.257.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.258.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.26.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.261.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.262.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.263.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.264.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.265.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.266.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.267.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.268.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.269.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.27.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.270.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.271.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.272.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.274.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.275.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.276.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.28.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.281.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.282.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.283.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.284.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.285.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.286.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.287.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.288.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.289.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.29.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.290.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.291.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.292.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.294.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.295.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.298.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.299.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.30.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.300.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.301.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.302.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.303.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.304.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.305.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.306.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.307.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.308.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.309.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.31.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.310.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.311.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.312.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.313.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.315.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.316.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.317.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.318.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.319.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.320.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.324.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.325.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.326.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.327.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.328.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.329.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.330.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.331.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.332.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.333.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.334.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.335.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.336.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.337.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.338.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.339.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.34.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.340.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.341.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.342.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.343.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.344.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.345.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.346.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.347.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.348.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.349.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.35.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.350.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.351.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.352.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.353.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.354.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.355.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.356.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.357.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.358.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.359.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.36.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.360.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.361.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.362.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.363.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.364.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.365.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.366.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.367.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.368.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.369.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.37.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.370.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.371.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.372.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.373.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.374.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.375.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.376.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.377.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.38.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.380.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.381.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.382.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.383.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.384.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.385.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.386.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.387.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.388.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.39.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.390.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.391.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.392.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.393.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.394.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.395.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.396.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.397.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.399.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.40.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.401.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.403.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.404.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.405.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.407.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.408.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.409.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.41.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.410.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.411.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.412.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.414.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.415.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.42.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.43.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.44.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.45.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.46.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.47.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.48.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.49.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.50.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.51.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.52.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.53.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.54.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.56.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.57.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.58.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.59.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.60.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.61.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.62.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.64.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.65.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.67.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.69.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.71.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.72.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.73.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.75.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.76.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.77.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.78.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.79.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.80.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.81.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.82.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.83.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.85.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.86.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.87.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.88.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.90.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.91.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.93.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.94.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.95.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.96.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B18.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B19.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B20.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B25.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B35.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B38.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B40.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B47.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B51.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B52.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B57.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.1.B61.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.B2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.2.B3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.13.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.15.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.16.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.17.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.20.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.21.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.30.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.37.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.38.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.40.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.41.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.42.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.43.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.44.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.45.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.46.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.47.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.48.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.3.B4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.5.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.9.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.98.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.98.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.98.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.98.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.98.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.13.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.14.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.18.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.20.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.21.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.22.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.24.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.27.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.28.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.29.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.30.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.31.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.32.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.35.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.36.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.37.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.38.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.39.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.40.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.41.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.42.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.B10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.1.99.B6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.14.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.15.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.16.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.3.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.5.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.10.9.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.11.1.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/1.11.1.10.tsv
# ...
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.39.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.41.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.42.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.43.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.44.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.45.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.46.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.47.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.48.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.49.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.51.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.52.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.B10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.B11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.B15.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.B16.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.B19.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.B2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.2.B3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.3.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.3.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.3.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.3.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.3.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.3.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.3.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.13.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.14.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.15.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.16.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.18.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.19.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.20.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.21.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.22.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.23.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.24.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.4.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.3.5.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.4.1.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.B1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.5.1.B3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.6.1.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/6.6.1.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.1.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.2.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.2.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.1.3.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.1.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.1.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.1.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.13.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.14.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.15.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.16.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.19.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.2.9.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.4.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.4.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.2.4.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.3.2.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.3.2.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.3.2.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.3.2.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.3.2.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.3.2.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.4.2.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.5.2.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.5.2.3.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.5.2.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.5.2.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.5.2.6.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.1.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.10.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.11.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.12.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.2.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.4.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.5.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.7.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.8.tsv
# Loading /data/Work/projects/sampling_1.1.3.15/data/intermediate/BRENDA_for_paper/aln_temp_data/7.6.2.9.tsv
# done
